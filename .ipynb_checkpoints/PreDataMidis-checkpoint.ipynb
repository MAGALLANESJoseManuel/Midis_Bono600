# %%
import pandas as pd

yanapaybd=pd.read_excel("AvanceDetalladoDelBonoYanapay.xlsx",3)
yanapaybd.columns
# Out:
# Index(['BD', 'UBIGEO', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'GENERO',
#        'MODALIDAD_FINAL', 'IDMODALIDAD', 'MODALIDAD_MOSTRAR', 'AREA',
#        'PROGRAMADO', 'EJECUTADO', 'GRUPO', 'FECHA_ACTUALIZACION'],
#       dtype='object')

# %%
yanapayDis=yanapaybd.groupby(['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA','DISTRITO']).agg({'PROGRAMADO': 'sum','EJECUTADO':'sum'})
yanapayDis
# Out:
#                                                         PROGRAMADO  EJECUTADO
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                  12656      12126
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                       181        176
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                         848        790
# 10104  AMAZONAS     CHACHAPOYAS CHETO                          505        490
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                      513        486
# ...                                                            ...        ...
# 250302 UCAYALI      PADRE ABAD  IRAZOLA                       7881       6822
# 250303 UCAYALI      PADRE ABAD  CURIMANA                      6258       5567
# 250304 UCAYALI      PADRE ABAD  NESHUYA                       4057       3731
# 250305 UCAYALI      PADRE ABAD  ALEXANDER VON HUMBOLDT        3396       3017
# 250401 UCAYALI      PURUS       PURUS                         2365       2065
#
# [1874 rows x 2 columns]

# %%
yanapayDis.reset_index(inplace=True)
yanapayDis
# Out:
#       UBIGEO DEPARTAMENTO    PROVINCIA                DISTRITO  PROGRAMADO  \
# 0      10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS       12656
# 1      10102     AMAZONAS  CHACHAPOYAS                ASUNCION         181
# 2      10103     AMAZONAS  CHACHAPOYAS                  BALSAS         848
# 3      10104     AMAZONAS  CHACHAPOYAS                   CHETO         505
# 4      10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN         513
# ...      ...          ...          ...                     ...         ...
# 1869  250302      UCAYALI   PADRE ABAD                 IRAZOLA        7881
# 1870  250303      UCAYALI   PADRE ABAD                CURIMANA        6258
# 1871  250304      UCAYALI   PADRE ABAD                 NESHUYA        4057
# 1872  250305      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT        3396
# 1873  250401      UCAYALI        PURUS                   PURUS        2365
#
#       EJECUTADO
# 0         12126
# 1           176
# 2           790
# 3           490
# 4           486
# ...         ...
# 1869       6822
# 1870       5567
# 1871       3731
# 1872       3017
# 1873       2065
#
# [1874 rows x 6 columns]

# %%
yanapayDis.to_csv("yanapayDis.csv",index=False)

# %%
congre=pd.read_csv("Congresal_total_eg2021.csv",sep=';')

# %%
len(set(congre.DEPARTAMENTO )& set(yanapayDis.DEPARTAMENTO)),len(set(congre.PROVINCIA )& set(yanapayDis.PROVINCIA))
# Out:
# (25, 196)

# %%
congre=congre[congre.DEPARTAMENTO.isin(set(yanapayDis.DEPARTAMENTO))]
congre=congre[congre.PROVINCIA.isin(set(yanapayDis.PROVINCIA))]
congre
# Out:
#          UBIGEO DEPARTAMENTO    PROVINCIA     DISTRITO TIPO_ELECCION  \
# 105       10101     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS     CONGRESAL
# 106       10101     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS     CONGRESAL
# 107       10101     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS     CONGRESAL
# 108       10101     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS     CONGRESAL
# 109       10101     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS     CONGRESAL
# ...         ...          ...          ...          ...           ...
# 1861391  250302      UCAYALI      ATALAYA     TAHUANIA     CONGRESAL
# 1861392  250302      UCAYALI      ATALAYA     TAHUANIA     CONGRESAL
# 1861393  250302      UCAYALI      ATALAYA     TAHUANIA     CONGRESAL
# 1861394  250302      UCAYALI      ATALAYA     TAHUANIA     CONGRESAL
# 1861395  250302      UCAYALI      ATALAYA     TAHUANIA     CONGRESAL
#
#          MESA_DE_VOTACION DESCRIP_ESTADO_ACTA  TIPO_OBSERVACION  \
# 105                     1       CONTABILIZADA               NaN
# 106                     1       CONTABILIZADA               NaN
# 107                     1       CONTABILIZADA               NaN
# 108                     1       CONTABILIZADA               NaN
# 109                     1       CONTABILIZADA               NaN
# ...                   ...                 ...               ...
# 1861391            903108       CONTABILIZADA               NaN
# 1861392            903108       CONTABILIZADA               NaN
# 1861393            903108       CONTABILIZADA               NaN
# 1861394            903108       CONTABILIZADA               NaN
# 1861395            903108       CONTABILIZADA               NaN
#
#          UBICACION_EN_CEDULA  CODIGO_OP  ... N_VOTOS_27  N_VOTOS_28  \
# 105                        1          6  ...        NaN         NaN
# 106                        2         12  ...        NaN         NaN
# 107                        3          5  ...        NaN         NaN
# 108                        4         11  ...        NaN         NaN
# 109                        6         22  ...        NaN         NaN
# ...                      ...        ...  ...        ...         ...
# 1861391                   18         14  ...        NaN         NaN
# 1861392                   20          2  ...        NaN         NaN
# 1861393                   80         80  ...        NaN         NaN
# 1861394                   81         81  ...        NaN         NaN
# 1861395                   82         82  ...        NaN         NaN
#
#          N_VOTOS_29  N_VOTOS_30  N_VOTOS_31  N_VOTOS_32  N_VOTOS_33  \
# 105             NaN         NaN         NaN         NaN         NaN
# 106             NaN         NaN         NaN         NaN         NaN
# 107             NaN         NaN         NaN         NaN         NaN
# 108             NaN         NaN         NaN         NaN         NaN
# 109             NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 1861391         NaN         NaN         NaN         NaN         NaN
# 1861392         NaN         NaN         NaN         NaN         NaN
# 1861393         NaN         NaN         NaN         NaN         NaN
# 1861394         NaN         NaN         NaN         NaN         NaN
# 1861395         NaN         NaN         NaN         NaN         NaN
#
#          N_VOTOS_34  N_CVAS  N_ELEC_HABIL
# 105             NaN   181.0           300
# 106             NaN   181.0           300
# 107             NaN   181.0           300
# 108             NaN   181.0           300
# 109             NaN   181.0           300
# ...             ...     ...           ...
# 1861391         NaN   157.0           292
# 1861392         NaN   157.0           292
# 1861393         NaN   157.0           292
# 1861394         NaN   157.0           292
# 1861395         NaN   157.0           292
#
# [1789156 rows x 48 columns]

# %%
len(set(congre.DISTRITO))
# Out:
# 1722

# %%
congre.DESCRIP_ESTADO_ACTA.value_counts()
# Out:
# CONTABILIZADA             1478689
# COMPUTADA RESUELTA         324547
# ANULADA                     46043
# SIN INSTALAR                10478
# ACTA RESUELTA                 780
# ACTA ANULADA                  667
# ANULADA POR EXTRAVIADA        192
# Name: DESCRIP_ESTADO_ACTA, dtype: int64

# %%
congreDis.reset_index(inplace=True)
congreDis.columns
# Out:
# Index(['level_0', 'index', 'UBIGEO', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO',
#        'TIPO_ELECCION', 'MESA_DE_VOTACION', 'DESCRIP_ESTADO_ACTA',
#        'TIPO_OBSERVACION', 'UBICACION_EN_CEDULA', 'CODIGO_OP',
#        'DESCRIPCION_OP', 'N_TOTAL_VOTOS', 'N_VOTOS_1', 'N_VOTOS_2',
#        'N_VOTOS_3', 'N_VOTOS_4', 'N_VOTOS_5', 'N_VOTOS_6', 'N_VOTOS_7',
#        'N_VOTOS_8', 'N_VOTOS_9', 'N_VOTOS_10', 'N_VOTOS_11', 'N_VOTOS_12',
#        'N_VOTOS_13', 'N_VOTOS_14', 'N_VOTOS_15', 'N_VOTOS_16', 'N_VOTOS_17',
#        'N_VOTOS_18', 'N_VOTOS_19', 'N_VOTOS_20', 'N_VOTOS_21', 'N_VOTOS_22',
#        'N_VOTOS_23', 'N_VOTOS_24', 'N_VOTOS_25', 'N_VOTOS_26', 'N_VOTOS_27',
#        'N_VOTOS_28', 'N_VOTOS_29', 'N_VOTOS_30', 'N_VOTOS_31', 'N_VOTOS_32',
#        'N_VOTOS_33', 'N_VOTOS_34', 'N_CVAS', 'N_ELEC_HABIL'],
#       dtype='object')

# %%
congreDis.DESCRIPCION_OP.value_counts()
# Out:
# FRENTE POPULAR AGRICOLA FIA DEL PERU - FREPAP     81118
# FUERZA POPULAR                                    81118
# VOTOS IMPUGNADOS                                  81118
# VOTOS NULOS                                       81118
# VOTOS EN BLANCO                                   81118
# ALIANZA PARA EL PROGRESO                          81118
# PARTIDO NACIONALISTA PERUANO                      81118
# RENOVACION POPULAR                                81118
# PODEMOS PERU                                      81118
# ACCION POPULAR                                    81118
# VICTORIA NACIONAL                                 81118
# PARTIDO MORADO                                    81118
# PARTIDO DEMOCRATICO SOMOS PERU                    80724
# JUNTOS POR EL PERU                                80599
# PARTIDO POPULAR CRISTIANO - PPC                   79634
# RENACIMIENTO UNIDO NACIONAL                       79096
# UNION POR EL PERU                                 77343
# DEMOCRACIA DIRECTA                                77126
# PARTIDO POLITICO NACIONAL PERU LIBRE              76038
# AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL       74329
# EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD    71698
# PERU PATRIA SEGURA                                52439
# PARTIDO POLITICO CONTIGO                          24223
# Name: DESCRIPCION_OP, dtype: int64

# %%
unidades=['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA','DISTRITO','DESCRIPCION_OP']
congreDisPartidos=congreDis.groupby(unidades).agg({'N_TOTAL_VOTOS':'sum'})
congreDisPartidos.reset_index(inplace=True)
unidades2=['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA','DISTRITO']
congreDisPartidosL=pd.pivot_table(congreDisPartidos,
                            values=['N_TOTAL_VOTOS'], 
                            index=unidades2,
                            columns=['DESCRIPCION_OP'],
                                 aggfunc=sum)
# Out:
#                                              N_TOTAL_VOTOS  \
# DESCRIPCION_OP                              ACCION POPULAR
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS          832.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION              17.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                60.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                 38.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN             24.0
# ...                                                    ...
# 250301 UCAYALI      ATALAYA     RAIMONDI            1302.0
# 250302 UCAYALI      ATALAYA     TAHUANIA             324.0
# 250303 UCAYALI      ATALAYA     YURUA                 38.0
# 250304 UCAYALI      ATALAYA     SEPAHUA              337.0
# 250401 UCAYALI      PURUS       PURUS                 35.0
#
#                                                                       \
# DESCRIPCION_OP                              ALIANZA PARA EL PROGRESO
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                   1336.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                         7.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                          30.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                           26.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                       15.0
# ...                                                              ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                       212.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                       113.0
# 250303 UCAYALI      ATALAYA     YURUA                           55.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                        150.0
# 250401 UCAYALI      PURUS       PURUS                          391.0
#
#                                                                                          \
# DESCRIPCION_OP                              AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                                         NaN
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                            NaN
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                              NaN
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                               NaN
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                                           NaN
# ...                                                                                 ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                                            NaN
# 250302 UCAYALI      ATALAYA     TAHUANIA                                            NaN
# 250303 UCAYALI      ATALAYA     YURUA                                               NaN
# 250304 UCAYALI      ATALAYA     SEPAHUA                                             NaN
# 250401 UCAYALI      PURUS       PURUS                                               NaN
#
#                                                                 \
# DESCRIPCION_OP                              DEMOCRACIA DIRECTA
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS               27.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                   0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                     0.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                      0.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                  1.0
# ...                                                        ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                   NaN
# 250302 UCAYALI      ATALAYA     TAHUANIA                   NaN
# 250303 UCAYALI      ATALAYA     YURUA                      NaN
# 250304 UCAYALI      ATALAYA     SEPAHUA                    NaN
# 250401 UCAYALI      PURUS       PURUS                      NaN
#
#                                                                                             \
# DESCRIPCION_OP                              EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                                          391.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                               0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                                 5.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                                 58.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                                              7.0
# ...                                                                                    ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                                               NaN
# 250302 UCAYALI      ATALAYA     TAHUANIA                                               NaN
# 250303 UCAYALI      ATALAYA     YURUA                                                  NaN
# 250304 UCAYALI      ATALAYA     SEPAHUA                                                NaN
# 250401 UCAYALI      PURUS       PURUS                                                  NaN
#
#                                                                                            \
# DESCRIPCION_OP                              FRENTE POPULAR AGRICOLA FIA DEL PERU - FREPAP
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                                         127.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                              0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                               15.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                                 1.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                                             0.0
# ...                                                                                   ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                                            456.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                                             38.0
# 250303 UCAYALI      ATALAYA     YURUA                                                 0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                                             288.0
# 250401 UCAYALI      PURUS       PURUS                                                 4.0
#
#                                                                                \
# DESCRIPCION_OP                              FUERZA POPULAR JUNTOS POR EL PERU
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS          711.0             1218.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION               6.0                5.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                54.0               25.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                 19.0               23.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN             59.0               15.0
# ...                                                    ...                ...
# 250301 UCAYALI      ATALAYA     RAIMONDI            1470.0              515.0
# 250302 UCAYALI      ATALAYA     TAHUANIA             315.0              250.0
# 250303 UCAYALI      ATALAYA     YURUA                124.0                0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA              567.0               57.0
# 250401 UCAYALI      PURUS       PURUS                119.0               22.0
#
#                                                                             \
# DESCRIPCION_OP                              PARTIDO DEMOCRATICO SOMOS PERU
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                         1289.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                               5.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                24.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                 15.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                             13.0
# ...                                                                    ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                             151.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                             167.0
# 250303 UCAYALI      ATALAYA     YURUA                                  5.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                               36.0
# 250401 UCAYALI      PURUS       PURUS                                 47.0
#
#                                                             ...  \
# DESCRIPCION_OP                              PARTIDO MORADO  ...
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO                    ...
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS          661.0  ...
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION               2.0  ...
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                 6.0  ...
# 10104  AMAZONAS     CHACHAPOYAS CHETO                  8.0  ...
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN              3.0  ...
# ...                                                    ...  ...
# 250301 UCAYALI      ATALAYA     RAIMONDI              50.0  ...
# 250302 UCAYALI      ATALAYA     TAHUANIA              16.0  ...
# 250303 UCAYALI      ATALAYA     YURUA                  0.0  ...
# 250304 UCAYALI      ATALAYA     SEPAHUA               25.0  ...
# 250401 UCAYALI      PURUS       PURUS                  5.0  ...
#
#                                                                              \
# DESCRIPCION_OP                              PARTIDO POPULAR CRISTIANO - PPC
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                            67.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                  3.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                   3.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                               0.0
# ...                                                                     ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                             2083.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                               52.0
# 250303 UCAYALI      ATALAYA     YURUA                                   0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                                50.0
# 250401 UCAYALI      PURUS       PURUS                                  15.0
#
#                                                                              \
# DESCRIPCION_OP                              PERU PATRIA SEGURA PODEMOS PERU
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                NaN        398.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                   NaN          0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                     NaN          8.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                      NaN          1.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                  NaN          3.0
# ...                                                        ...          ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                   NaN        133.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                   NaN         29.0
# 250303 UCAYALI      ATALAYA     YURUA                      NaN          0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                    NaN         52.0
# 250401 UCAYALI      PURUS       PURUS                      NaN         14.0
#
#                                                                          \
# DESCRIPCION_OP                              RENACIMIENTO UNIDO NACIONAL
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                        34.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                            1.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                              1.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                               0.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                           2.0
# ...                                                                 ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                           43.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                           35.0
# 250303 UCAYALI      ATALAYA     YURUA                               1.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                             5.0
# 250401 UCAYALI      PURUS       PURUS                               5.0
#
#                                                                 \
# DESCRIPCION_OP                              RENOVACION POPULAR
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS              577.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                   4.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                    19.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                     15.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                  3.0
# ...                                                        ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                 171.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                  28.0
# 250303 UCAYALI      ATALAYA     YURUA                      2.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                   19.0
# 250401 UCAYALI      PURUS       PURUS                      4.0
#
#                                                                \
# DESCRIPCION_OP                              UNION POR EL PERU
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS              97.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                  1.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                    1.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                     3.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                 3.0
# ...                                                       ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                110.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                 19.0
# 250303 UCAYALI      ATALAYA     YURUA                     0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                  12.0
# 250401 UCAYALI      PURUS       PURUS                     7.0
#
#                                                                                \
# DESCRIPCION_OP                              VICTORIA NACIONAL VOTOS EN BLANCO
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS             511.0          2149.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                  3.0            22.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                   20.0            88.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                     7.0           112.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                 3.0            90.0
# ...                                                       ...             ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                 90.0          2638.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                 33.0           789.0
# 250303 UCAYALI      ATALAYA     YURUA                     2.0            87.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                  48.0           587.0
# 250401 UCAYALI      PURUS       PURUS                     6.0           320.0
#
#
# DESCRIPCION_OP                              VOTOS IMPUGNADOS VOTOS NULOS
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS              0.0      2169.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                 0.0        20.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                   0.0        36.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                    0.0        48.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                0.0        54.0
# ...                                                      ...         ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                 0.0      2779.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                 0.0       392.0
# 250303 UCAYALI      ATALAYA     YURUA                    0.0        70.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                  0.0       301.0
# 250401 UCAYALI      PURUS       PURUS                    0.0       233.0
#
# [1874 rows x 23 columns]

# %%
congreDisPartidosL.columns=[b for a,b in congreDisPartidosL.columns]
# Out:
#                                              ACCION POPULAR  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS           832.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION               17.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                 60.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                  38.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN              24.0
# ...                                                     ...
# 250301 UCAYALI      ATALAYA     RAIMONDI             1302.0
# 250302 UCAYALI      ATALAYA     TAHUANIA              324.0
# 250303 UCAYALI      ATALAYA     YURUA                  38.0
# 250304 UCAYALI      ATALAYA     SEPAHUA               337.0
# 250401 UCAYALI      PURUS       PURUS                  35.0
#
#                                              ALIANZA PARA EL PROGRESO  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                    1336.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                          7.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                           30.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                            26.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                        15.0
# ...                                                               ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                        212.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                        113.0
# 250303 UCAYALI      ATALAYA     YURUA                            55.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                         150.0
# 250401 UCAYALI      PURUS       PURUS                           391.0
#
#                                              AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                                          NaN
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                             NaN
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                               NaN
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                                NaN
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                                            NaN
# ...                                                                                  ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                                             NaN
# 250302 UCAYALI      ATALAYA     TAHUANIA                                             NaN
# 250303 UCAYALI      ATALAYA     YURUA                                                NaN
# 250304 UCAYALI      ATALAYA     SEPAHUA                                              NaN
# 250401 UCAYALI      PURUS       PURUS                                                NaN
#
#                                              DEMOCRACIA DIRECTA  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                27.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                    0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                      0.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                       0.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                   1.0
# ...                                                         ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                    NaN
# 250302 UCAYALI      ATALAYA     TAHUANIA                    NaN
# 250303 UCAYALI      ATALAYA     YURUA                       NaN
# 250304 UCAYALI      ATALAYA     SEPAHUA                     NaN
# 250401 UCAYALI      PURUS       PURUS                       NaN
#
#                                              EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                                           391.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                                0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                                  5.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                                  58.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                                               7.0
# ...                                                                                     ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                                                NaN
# 250302 UCAYALI      ATALAYA     TAHUANIA                                                NaN
# 250303 UCAYALI      ATALAYA     YURUA                                                   NaN
# 250304 UCAYALI      ATALAYA     SEPAHUA                                                 NaN
# 250401 UCAYALI      PURUS       PURUS                                                   NaN
#
#                                              FRENTE POPULAR AGRICOLA FIA DEL PERU - FREPAP  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                                          127.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                               0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                                15.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                                  1.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                                              0.0
# ...                                                                                    ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                                             456.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                                              38.0
# 250303 UCAYALI      ATALAYA     YURUA                                                  0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                                              288.0
# 250401 UCAYALI      PURUS       PURUS                                                  4.0
#
#                                              FUERZA POPULAR  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS           711.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                6.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                 54.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                  19.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN              59.0
# ...                                                     ...
# 250301 UCAYALI      ATALAYA     RAIMONDI             1470.0
# 250302 UCAYALI      ATALAYA     TAHUANIA              315.0
# 250303 UCAYALI      ATALAYA     YURUA                 124.0
# 250304 UCAYALI      ATALAYA     SEPAHUA               567.0
# 250401 UCAYALI      PURUS       PURUS                 119.0
#
#                                              JUNTOS POR EL PERU  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS              1218.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                    5.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                     25.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                      23.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                  15.0
# ...                                                         ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                  515.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                  250.0
# 250303 UCAYALI      ATALAYA     YURUA                       0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                    57.0
# 250401 UCAYALI      PURUS       PURUS                      22.0
#
#                                              PARTIDO DEMOCRATICO SOMOS PERU  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                          1289.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                5.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                 24.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                  15.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                              13.0
# ...                                                                     ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                              151.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                              167.0
# 250303 UCAYALI      ATALAYA     YURUA                                   5.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                                36.0
# 250401 UCAYALI      PURUS       PURUS                                  47.0
#
#                                              PARTIDO MORADO  ...  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO                     ...
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS           661.0  ...
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                2.0  ...
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                  6.0  ...
# 10104  AMAZONAS     CHACHAPOYAS CHETO                   8.0  ...
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN               3.0  ...
# ...                                                     ...  ...
# 250301 UCAYALI      ATALAYA     RAIMONDI               50.0  ...
# 250302 UCAYALI      ATALAYA     TAHUANIA               16.0  ...
# 250303 UCAYALI      ATALAYA     YURUA                   0.0  ...
# 250304 UCAYALI      ATALAYA     SEPAHUA                25.0  ...
# 250401 UCAYALI      PURUS       PURUS                   5.0  ...
#
#                                              PARTIDO POPULAR CRISTIANO - PPC  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                             67.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                                 0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                                   3.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                    3.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                                0.0
# ...                                                                      ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                              2083.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                                52.0
# 250303 UCAYALI      ATALAYA     YURUA                                    0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                                 50.0
# 250401 UCAYALI      PURUS       PURUS                                   15.0
#
#                                              PERU PATRIA SEGURA  PODEMOS PERU  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                 NaN         398.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                    NaN           0.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                      NaN           8.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                       NaN           1.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                   NaN           3.0
# ...                                                         ...           ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                    NaN         133.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                    NaN          29.0
# 250303 UCAYALI      ATALAYA     YURUA                       NaN           0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                     NaN          52.0
# 250401 UCAYALI      PURUS       PURUS                       NaN          14.0
#
#                                              RENACIMIENTO UNIDO NACIONAL  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS                         34.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                             1.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                               1.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                                0.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                            2.0
# ...                                                                  ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                            43.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                            35.0
# 250303 UCAYALI      ATALAYA     YURUA                                1.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                              5.0
# 250401 UCAYALI      PURUS       PURUS                                5.0
#
#                                              RENOVACION POPULAR  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS               577.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                    4.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                     19.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                      15.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                   3.0
# ...                                                         ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                  171.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                   28.0
# 250303 UCAYALI      ATALAYA     YURUA                       2.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                    19.0
# 250401 UCAYALI      PURUS       PURUS                       4.0
#
#                                              UNION POR EL PERU  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS               97.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                   1.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                     1.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                      3.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                  3.0
# ...                                                        ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                 110.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                  19.0
# 250303 UCAYALI      ATALAYA     YURUA                      0.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                   12.0
# 250401 UCAYALI      PURUS       PURUS                      7.0
#
#                                              VICTORIA NACIONAL  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS              511.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                   3.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                    20.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                      7.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                  3.0
# ...                                                        ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                  90.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                  33.0
# 250303 UCAYALI      ATALAYA     YURUA                      2.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                   48.0
# 250401 UCAYALI      PURUS       PURUS                      6.0
#
#                                              VOTOS EN BLANCO  \
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS           2149.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                22.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                  88.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                  112.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN               90.0
# ...                                                      ...
# 250301 UCAYALI      ATALAYA     RAIMONDI              2638.0
# 250302 UCAYALI      ATALAYA     TAHUANIA               789.0
# 250303 UCAYALI      ATALAYA     YURUA                   87.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                587.0
# 250401 UCAYALI      PURUS       PURUS                  320.0
#
#                                              VOTOS IMPUGNADOS  VOTOS NULOS
# UBIGEO DEPARTAMENTO PROVINCIA   DISTRITO
# 10101  AMAZONAS     CHACHAPOYAS CHACHAPOYAS               0.0       2169.0
# 10102  AMAZONAS     CHACHAPOYAS ASUNCION                  0.0         20.0
# 10103  AMAZONAS     CHACHAPOYAS BALSAS                    0.0         36.0
# 10104  AMAZONAS     CHACHAPOYAS CHETO                     0.0         48.0
# 10105  AMAZONAS     CHACHAPOYAS CHILIQUIN                 0.0         54.0
# ...                                                       ...          ...
# 250301 UCAYALI      ATALAYA     RAIMONDI                  0.0       2779.0
# 250302 UCAYALI      ATALAYA     TAHUANIA                  0.0        392.0
# 250303 UCAYALI      ATALAYA     YURUA                     0.0         70.0
# 250304 UCAYALI      ATALAYA     SEPAHUA                   0.0        301.0
# 250401 UCAYALI      PURUS       PURUS                     0.0        233.0
#
# [1874 rows x 23 columns]

# %%
congreDisPartidosL.reset_index(inplace=True)
# Out:
#       UBIGEO DEPARTAMENTO    PROVINCIA     DISTRITO  ACCION POPULAR  \
# 0      10101     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS           832.0
# 1      10102     AMAZONAS  CHACHAPOYAS     ASUNCION            17.0
# 2      10103     AMAZONAS  CHACHAPOYAS       BALSAS            60.0
# 3      10104     AMAZONAS  CHACHAPOYAS        CHETO            38.0
# 4      10105     AMAZONAS  CHACHAPOYAS    CHILIQUIN            24.0
# ...      ...          ...          ...          ...             ...
# 1869  250301      UCAYALI      ATALAYA     RAIMONDI          1302.0
# 1870  250302      UCAYALI      ATALAYA     TAHUANIA           324.0
# 1871  250303      UCAYALI      ATALAYA        YURUA            38.0
# 1872  250304      UCAYALI      ATALAYA      SEPAHUA           337.0
# 1873  250401      UCAYALI        PURUS        PURUS            35.0
#
#       ALIANZA PARA EL PROGRESO  AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL  \
# 0                       1336.0                                          NaN
# 1                          7.0                                          NaN
# 2                         30.0                                          NaN
# 3                         26.0                                          NaN
# 4                         15.0                                          NaN
# ...                        ...                                          ...
# 1869                     212.0                                          NaN
# 1870                     113.0                                          NaN
# 1871                      55.0                                          NaN
# 1872                     150.0                                          NaN
# 1873                     391.0                                          NaN
#
#       DEMOCRACIA DIRECTA  EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD  \
# 0                   27.0                                           391.0
# 1                    0.0                                             0.0
# 2                    0.0                                             5.0
# 3                    0.0                                            58.0
# 4                    1.0                                             7.0
# ...                  ...                                             ...
# 1869                 NaN                                             NaN
# 1870                 NaN                                             NaN
# 1871                 NaN                                             NaN
# 1872                 NaN                                             NaN
# 1873                 NaN                                             NaN
#
#       FRENTE POPULAR AGRICOLA FIA DEL PERU - FREPAP  ...  \
# 0                                             127.0  ...
# 1                                               0.0  ...
# 2                                              15.0  ...
# 3                                               1.0  ...
# 4                                               0.0  ...
# ...                                             ...  ...
# 1869                                          456.0  ...
# 1870                                           38.0  ...
# 1871                                            0.0  ...
# 1872                                          288.0  ...
# 1873                                            4.0  ...
#
#       PARTIDO POPULAR CRISTIANO - PPC  PERU PATRIA SEGURA  PODEMOS PERU  \
# 0                                67.0                 NaN         398.0
# 1                                 0.0                 NaN           0.0
# 2                                 3.0                 NaN           8.0
# 3                                 3.0                 NaN           1.0
# 4                                 0.0                 NaN           3.0
# ...                               ...                 ...           ...
# 1869                           2083.0                 NaN         133.0
# 1870                             52.0                 NaN          29.0
# 1871                              0.0                 NaN           0.0
# 1872                             50.0                 NaN          52.0
# 1873                             15.0                 NaN          14.0
#
#       RENACIMIENTO UNIDO NACIONAL  RENOVACION POPULAR  UNION POR EL PERU  \
# 0                            34.0               577.0               97.0
# 1                             1.0                 4.0                1.0
# 2                             1.0                19.0                1.0
# 3                             0.0                15.0                3.0
# 4                             2.0                 3.0                3.0
# ...                           ...                 ...                ...
# 1869                         43.0               171.0              110.0
# 1870                         35.0                28.0               19.0
# 1871                          1.0                 2.0                0.0
# 1872                          5.0                19.0               12.0
# 1873                          5.0                 4.0                7.0
#
#       VICTORIA NACIONAL  VOTOS EN BLANCO  VOTOS IMPUGNADOS  VOTOS NULOS
# 0                 511.0           2149.0               0.0       2169.0
# 1                   3.0             22.0               0.0         20.0
# 2                  20.0             88.0               0.0         36.0
# 3                   7.0            112.0               0.0         48.0
# 4                   3.0             90.0               0.0         54.0
# ...                 ...              ...               ...          ...
# 1869               90.0           2638.0               0.0       2779.0
# 1870               33.0            789.0               0.0        392.0
# 1871                2.0             87.0               0.0         70.0
# 1872               48.0            587.0               0.0        301.0
# 1873                6.0            320.0               0.0        233.0
#
# [1874 rows x 27 columns]

# %%
congreDisPartidosL["TotalEmitido"]=congreDisPartidosL.iloc[:,4::].sum(axis=1)

# %%
selection3=['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO','PARTIDO POLITICO NACIONAL PERU LIBRE','TotalEmitido']
congreDisPeruLibre=congreDisPartidosL.loc[:,selection3]
congreDisPeruLibre
# Out:
#       UBIGEO DEPARTAMENTO    PROVINCIA     DISTRITO  \
# 0      10101     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 1      10102     AMAZONAS  CHACHAPOYAS     ASUNCION
# 2      10103     AMAZONAS  CHACHAPOYAS       BALSAS
# 3      10104     AMAZONAS  CHACHAPOYAS        CHETO
# 4      10105     AMAZONAS  CHACHAPOYAS    CHILIQUIN
# ...      ...          ...          ...          ...
# 1869  250301      UCAYALI      ATALAYA     RAIMONDI
# 1870  250302      UCAYALI      ATALAYA     TAHUANIA
# 1871  250303      UCAYALI      ATALAYA        YURUA
# 1872  250304      UCAYALI      ATALAYA      SEPAHUA
# 1873  250401      UCAYALI        PURUS        PURUS
#
#       PARTIDO POLITICO NACIONAL PERU LIBRE  TotalEmitido
# 0                                    718.0       13427.0
# 1                                      5.0         114.0
# 2                                     97.0         504.0
# 3                                     19.0         411.0
# 4                                     18.0         324.0
# ...                                    ...           ...
# 1869                                 678.0       12972.0
# 1870                                 293.0        2967.0
# 1871                                   8.0         393.0
# 1872                                 107.0        2657.0
# 1873                                  51.0        1282.0
#
# [1874 rows x 6 columns]

# %%
congreDisPeruLibre['proporcion']=congreDisPeruLibre.iloc[:,4]/congreDisPeruLibre.iloc[:,5]

# %%
congreDisPeruLibre.to_csv('congreDisPeruLibre.csv',index=False)

# %%
theKeys=['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO']
yanapayDis.merge(congreDisPeruLibre,on=theKeys)
# Out:
#       UBIGEO_x DEPARTAMENTO    PROVINCIA                DISTRITO  PROGRAMADO  \
# 0        10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS       12656
# 1        10102     AMAZONAS  CHACHAPOYAS                ASUNCION         181
# 2        10103     AMAZONAS  CHACHAPOYAS                  BALSAS         848
# 3        10104     AMAZONAS  CHACHAPOYAS                   CHETO         505
# 4        10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN         513
# ...        ...          ...          ...                     ...         ...
# 1854    250302      UCAYALI   PADRE ABAD                 IRAZOLA        7881
# 1855    250303      UCAYALI   PADRE ABAD                CURIMANA        6258
# 1856    250304      UCAYALI   PADRE ABAD                 NESHUYA        4057
# 1857    250305      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT        3396
# 1858    250401      UCAYALI        PURUS                   PURUS        2365
#
#       EJECUTADO  UBIGEO_y  PARTIDO POLITICO NACIONAL PERU LIBRE  TotalEmitido  \
# 0         12126     10101                                 718.0       13427.0
# 1           176     10102                                   5.0         114.0
# 2           790     10103                                  97.0         504.0
# 3           490     10104                                  19.0         411.0
# 4           486     10105                                  18.0         324.0
# ...         ...       ...                                   ...           ...
# 1854       6822    250202                                1149.0        6535.0
# 1855       5567    250203                                 896.0        4142.0
# 1856       3731    250204                                 526.0        3854.0
# 1857       3017    250205                                 457.0        2670.0
# 1858       2065    250401                                  51.0        1282.0
#
#       proporcion
# 0       0.053474
# 1       0.043860
# 2       0.192460
# 3       0.046229
# 4       0.055556
# ...          ...
# 1854    0.175822
# 1855    0.216321
# 1856    0.136482
# 1857    0.171161
# 1858    0.039782
#
# [1859 rows x 10 columns]

# %%
set(yanapayDis.PROVINCIA)^set(congreDisPeruLibre.PROVINCIA)
# Out:
# set()

# %%
yanapayDis['PROVINCIA']=yanapayDis.PROVINCIA.str.replace(pat='ANTONIO RAYMONDI',repl='ANTONIO RAIMONDI',regex=False)

# %%
InYANAnotCONGRE=list(set(yanapayDis.DISTRITO)-set(congreDisPeruLibre.DISTRITO))
InYANAnotCONGRE
# Out:
# ['HUAYLLAY GRANDE',
#  'MILPUC',
#  'RAYMONDI',
#  'CASPISAPA',
#  'GAMARRA',
#  'SAN JUAN DE ISCOS',
#  'SANTA RITA DE SIGUAS',
#  'ESTIQUE-PAMPA',
#  'HUAYA',
#  'TOMAY KICHWA',
#  'CAPAZO',
#  'SANTA CRUZ DE TOLEDO',
#  'CARMEN DE LA LEGUA REYNOSO',
#  'QUISQUI (KICHKI)',
#  'RINCONADA LLICUAR']

# %%
InCONGREnotYANA=list(set(congreDisPeruLibre.DISTRITO)-set(yanapayDis.DISTRITO))
InCONGREnotYANA
# Out:
# ['HUALLA',
#  'CARMEN DE LA LEGUA-REYNOSO',
#  'CASPIZAPA',
#  'SANTA CRUZ DE TOLED',
#  'ESTIQUE PAMPA',
#  'MILPUCC',
#  'HUALLAY-GRANDE',
#  'RAIMONDI',
#  'QUISQUI',
#  'CAPASO',
#  'TOMAY-KICHWA',
#  'SAN JUAN DE YSCOS',
#  'SANTA RITA DE SIHUAS',
#  'MARISCAL GAMARRA',
#  'RINCONADA-LLICUAR']

# %%
congreDisPeruLibre[congreDisPeruLibre.DISTRITO.str.contains("CAPASO")]
# Out:
#       UBIGEO DEPARTAMENTO  PROVINCIA DISTRITO  \
# 1726  201204         PUNO  EL COLLAO   CAPASO
#
#       PARTIDO POLITICO NACIONAL PERU LIBRE  TotalEmitido  proporcion
# 1726                                 121.0         483.0    0.250518

# %%
# Out:
# [('CAPAZO', ('CAPASO', 83)),
#  ('CARMEN DE LA LEGUA REYNOSO', ('CARMEN DE LA LEGUA-REYNOSO', 100)),
#  ('CASPISAPA', ('CASPIZAPA', 89)),
#  ('ESTIQUE-PAMPA', ('ESTIQUE PAMPA', 100)),
#  ('GAMARRA', ('MARISCAL GAMARRA', 90)),
#  ('HUAYA', ('HUALLA', 73)),
#  ('HUAYLLAY GRANDE', ('HUALLAY-GRANDE', 97)),
#  ('MILPUC', ('MILPUCC', 92)),
#  ('QUISQUI (KICHKI)', ('QUISQUI', 90)),
#  ('RAYMONDI', ('RAIMONDI', 88)),
#  ('RINCONADA LLICUAR', ('RINCONADA-LLICUAR', 100)),
#  ('SAN JUAN DE ISCOS', ('SAN JUAN DE YSCOS', 94)),
#  ('SANTA CRUZ DE TOLEDO', ('SANTA CRUZ DE TOLED', 97)),
#  ('SANTA RITA DE SIGUAS', ('SANTA RITA DE SIHUAS', 95)),
#  ('TOMAY KICHWA', ('TOMAY-KICHWA', 100))]

# %%
changesYana={dis: process.extractOne(dis,InCONGREnotYANA)[0] for dis in sorted(InYANAnotCONGRE)}
changesYana
# Out:
# {'CAPAZO': 'CAPASO',
#  'CARMEN DE LA LEGUA REYNOSO': 'CARMEN DE LA LEGUA-REYNOSO',
#  'CASPISAPA': 'CASPIZAPA',
#  'ESTIQUE-PAMPA': 'ESTIQUE PAMPA',
#  'GAMARRA': 'MARISCAL GAMARRA',
#  'HUAYA': 'HUALLA',
#  'HUAYLLAY GRANDE': 'HUALLAY-GRANDE',
#  'MILPUC': 'MILPUCC',
#  'QUISQUI (KICHKI)': 'QUISQUI',
#  'RAYMONDI': 'RAIMONDI',
#  'RINCONADA LLICUAR': 'RINCONADA-LLICUAR',
#  'SAN JUAN DE ISCOS': 'SAN JUAN DE YSCOS',
#  'SANTA CRUZ DE TOLEDO': 'SANTA CRUZ DE TOLED',
#  'SANTA RITA DE SIGUAS': 'SANTA RITA DE SIHUAS',
#  'TOMAY KICHWA': 'TOMAY-KICHWA'}

# %%
yanapayDis.DISTRITO.replace(changesYana,inplace=True)

# %%
CongreYanay=yanapayDis.merge(congreDisPeruLibre,on=theKeys)
CongreYanay
# Out:
#       UBIGEO_x DEPARTAMENTO    PROVINCIA                DISTRITO  PROGRAMADO  \
# 0        10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS       12656
# 1        10102     AMAZONAS  CHACHAPOYAS                ASUNCION         181
# 2        10103     AMAZONAS  CHACHAPOYAS                  BALSAS         848
# 3        10104     AMAZONAS  CHACHAPOYAS                   CHETO         505
# 4        10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN         513
# ...        ...          ...          ...                     ...         ...
# 1869    250302      UCAYALI   PADRE ABAD                 IRAZOLA        7881
# 1870    250303      UCAYALI   PADRE ABAD                CURIMANA        6258
# 1871    250304      UCAYALI   PADRE ABAD                 NESHUYA        4057
# 1872    250305      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT        3396
# 1873    250401      UCAYALI        PURUS                   PURUS        2365
#
#       EJECUTADO  UBIGEO_y  PARTIDO POLITICO NACIONAL PERU LIBRE  TotalEmitido  \
# 0         12126     10101                                 718.0       13427.0
# 1           176     10102                                   5.0         114.0
# 2           790     10103                                  97.0         504.0
# 3           490     10104                                  19.0         411.0
# 4           486     10105                                  18.0         324.0
# ...         ...       ...                                   ...           ...
# 1869       6822    250202                                1149.0        6535.0
# 1870       5567    250203                                 896.0        4142.0
# 1871       3731    250204                                 526.0        3854.0
# 1872       3017    250205                                 457.0        2670.0
# 1873       2065    250401                                  51.0        1282.0
#
#       proporcion
# 0       0.053474
# 1       0.043860
# 2       0.192460
# 3       0.046229
# 4       0.055556
# ...          ...
# 1869    0.175822
# 1870    0.216321
# 1871    0.136482
# 1872    0.171161
# 1873    0.039782
#
# [1874 rows x 10 columns]

# %%
CongreYanay['yanaProp']=CongreYanay.EJECUTADO/CongreYanay.PROGRAMADO

# %%
CongreYanay.plot.scatter(x='yanaProp',y='proporcion',)
# Out:
# <AxesSubplot:xlabel='yanaProp', ylabel='proporcion'>

# %%
CongreYanay.to_csv('CongreYanay.csv',index=False)

# %%
Presis=pd.read_excel("1ra_vuelta_Version_PCM.xlsx")
Presis.columns
# Out:
# Index(['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'TIPO_ELECCION',
#        'MESA_DE_VOTACION', 'DESCRIP_ESTADO_ACTA', 'TIPO_OBSERVACION', 'N_CVAS',
#        'N_ELEC_HABIL', 'VOTOS_P1', 'VOTOS_P2', 'VOTOS_P3', 'VOTOS_P4',
#        'VOTOS_P5', 'VOTOS_P6', 'VOTOS_P7', 'VOTOS_P8', 'VOTOS_P9', 'VOTOS_P10',
#        'VOTOS_P11', 'VOTOS_P12', 'VOTOS_P13', 'VOTOS_P14', 'VOTOS_P15',
#        'VOTOS_P16', 'VOTOS_P17', 'VOTOS_P18', 'VOTOS_VB', 'VOTOS_VN',
#        'VOTOS_VI'],
#       dtype='object')

# %%
Presis['presiEmitidos']=Presis.iloc[:,10:].sum(axis=1)

# %%
Presis[Presis.N_CVAS!=Presis.presiEmitidos]
# Out:
#        UBIGEO DEPARTAMENTO PROVINCIA     DISTRITO TIPO_ELECCION  \
# 19     921001      AMERICA     CHILE  ANTOFAGASTA  PRESIDENCIAL
# 24     921006      AMERICA     CHILE     SANTIAGO  PRESIDENCIAL
# 25     921005      AMERICA     CHILE      IQUIQUE  PRESIDENCIAL
# 26     921006      AMERICA     CHILE     SANTIAGO  PRESIDENCIAL
# 27     921006      AMERICA     CHILE     SANTIAGO  PRESIDENCIAL
# ...       ...          ...       ...          ...           ...
# 85210  921006      AMERICA     CHILE     SANTIAGO  PRESIDENCIAL
# 85211  921006      AMERICA     CHILE     SANTIAGO  PRESIDENCIAL
# 85212  921006      AMERICA     CHILE     SANTIAGO  PRESIDENCIAL
# 85213  921006      AMERICA     CHILE     SANTIAGO  PRESIDENCIAL
# 85214  921006      AMERICA     CHILE     SANTIAGO  PRESIDENCIAL
#
#        MESA_DE_VOTACION DESCRIP_ESTADO_ACTA  TIPO_OBSERVACION  N_CVAS  \
# 19                80614        SIN INSTALAR               NaN     NaN
# 24                80970        SIN INSTALAR               NaN     NaN
# 25                80660        SIN INSTALAR               NaN     NaN
# 26                80720        SIN INSTALAR               NaN     NaN
# 27                80731        SIN INSTALAR               NaN     NaN
# ...                 ...                 ...               ...     ...
# 85210             80870        SIN INSTALAR               NaN     NaN
# 85211             80956        SIN INSTALAR               NaN     NaN
# 85212             80879        SIN INSTALAR               NaN     NaN
# 85213             80889        SIN INSTALAR               NaN     NaN
# 85214             80674        SIN INSTALAR               NaN     NaN
#
#        N_ELEC_HABIL  ...  VOTOS_P13  VOTOS_P14  VOTOS_P15  VOTOS_P16  \
# 19              296  ...        NaN        NaN        NaN        NaN
# 24              299  ...        NaN        NaN        NaN        NaN
# 25              297  ...        NaN        NaN        NaN        NaN
# 26              300  ...        NaN        NaN        NaN        NaN
# 27              300  ...        NaN        NaN        NaN        NaN
# ...             ...  ...        ...        ...        ...        ...
# 85210           300  ...        NaN        NaN        NaN        NaN
# 85211           299  ...        NaN        NaN        NaN        NaN
# 85212           300  ...        NaN        NaN        NaN        NaN
# 85213           300  ...        NaN        NaN        NaN        NaN
# 85214           300  ...        NaN        NaN        NaN        NaN
#
#        VOTOS_P17  VOTOS_P18  VOTOS_VB  VOTOS_VN  VOTOS_VI  presiEmitidos
# 19           NaN        NaN       NaN       NaN       NaN            0.0
# 24           NaN        NaN       NaN       NaN       NaN            0.0
# 25           NaN        NaN       NaN       NaN       NaN            0.0
# 26           NaN        NaN       NaN       NaN       NaN            0.0
# 27           NaN        NaN       NaN       NaN       NaN            0.0
# ...          ...        ...       ...       ...       ...            ...
# 85210        NaN        NaN       NaN       NaN       NaN            0.0
# 85211        NaN        NaN       NaN       NaN       NaN            0.0
# 85212        NaN        NaN       NaN       NaN       NaN            0.0
# 85213        NaN        NaN       NaN       NaN       NaN            0.0
# 85214        NaN        NaN       NaN       NaN       NaN            0.0
#
# [499 rows x 32 columns]

# %%
Presis.DESCRIP_ESTADO_ACTA.value_counts()
# Out:
# CONTABILIZADA             81924
# COMPUTADA RESUELTA         3081
# ANULADA                     949
# SIN INSTALAR                499
# EN PROCESO                   32
# ANULADA POR EXTRAVIADA        3
# Name: DESCRIP_ESTADO_ACTA, dtype: int64

# %%
Presis=Presis[Presis.DESCRIP_ESTADO_ACTA.isin(['CONTABILIZADA','COMPUTADA RESUELTA','ACTA RESUELTA'])]

# %%
Presis
# Out:
#        UBIGEO DEPARTAMENTO             PROVINCIA                DISTRITO  \
# 0       10101     AMAZONAS           CHACHAPOYAS             CHACHAPOYAS
# 1       10101     AMAZONAS           CHACHAPOYAS             CHACHAPOYAS
# 2       10204     AMAZONAS                 BAGUA                EL PARCO
# 3       10512     AMAZONAS  RODRIGUEZ DE MENDOZA            VISTA ALEGRE
# 4       10601     AMAZONAS          CONDORCANQUI                   NIEVA
# ...       ...          ...                   ...                     ...
# 86483  210609   SAN MARTIN            SAN MARTIN               HUIMBAYOC
# 86484  250205      UCAYALI            PADRE ABAD  ALEXANDER VON HUMBOLDT
# 86485  250301      UCAYALI               ATALAYA                RAIMONDI
# 86486  250302      UCAYALI               ATALAYA                TAHUANIA
# 86487  250301      UCAYALI               ATALAYA                RAIMONDI
#
#       TIPO_ELECCION  MESA_DE_VOTACION DESCRIP_ESTADO_ACTA  TIPO_OBSERVACION  \
# 0      PRESIDENCIAL                31       CONTABILIZADA               NaN
# 1      PRESIDENCIAL                54       CONTABILIZADA               NaN
# 2      PRESIDENCIAL               205       CONTABILIZADA               NaN
# 3      PRESIDENCIAL               576       CONTABILIZADA               NaN
# 4      PRESIDENCIAL               585       CONTABILIZADA               NaN
# ...             ...               ...                 ...               ...
# 86483  PRESIDENCIAL            903012       CONTABILIZADA               NaN
# 86484  PRESIDENCIAL             79806       CONTABILIZADA               NaN
# 86485  PRESIDENCIAL             79850       CONTABILIZADA               NaN
# 86486  PRESIDENCIAL             79907       CONTABILIZADA               NaN
# 86487  PRESIDENCIAL             79818       CONTABILIZADA               NaN
#
#        N_CVAS  N_ELEC_HABIL  ...  VOTOS_P13  VOTOS_P14  VOTOS_P15  VOTOS_P16  \
# 0        97.0           300  ...        3.0        NaN        1.0        4.0
# 1       204.0           300  ...       21.0        1.0        2.0       22.0
# 2       224.0           300  ...        7.0        3.0        1.0       54.0
# 3        81.0           247  ...        5.0        1.0        1.0       15.0
# 4       159.0           300  ...        4.0        NaN        NaN       28.0
# ...       ...           ...  ...        ...        ...        ...        ...
# 86483   158.0           188  ...        1.0        1.0        1.0        NaN
# 86484   175.0           238  ...        6.0        1.0        2.0       39.0
# 86485   193.0           300  ...        1.0        NaN        NaN       13.0
# 86486   146.0           300  ...        1.0        1.0        5.0       20.0
# 86487    97.0           291  ...        1.0        NaN        NaN        8.0
#
#        VOTOS_P17  VOTOS_P18  VOTOS_VB  VOTOS_VN  VOTOS_VI  presiEmitidos
# 0            NaN        3.0       NaN      20.0       NaN           97.0
# 1            NaN       30.0      19.0      15.0       NaN          204.0
# 2            NaN       15.0      37.0      14.0       NaN          224.0
# 3            NaN        NaN      28.0       2.0       NaN           81.0
# 4            NaN        2.0      27.0       8.0       NaN          159.0
# ...          ...        ...       ...       ...       ...            ...
# 86483        NaN        3.0      52.0      12.0       NaN          158.0
# 86484        NaN       11.0      55.0       5.0       NaN          175.0
# 86485        1.0        3.0      72.0      12.0       NaN          193.0
# 86486        NaN        3.0      37.0      11.0       NaN          146.0
# 86487        NaN        2.0      47.0       9.0       NaN           97.0
#
# [85005 rows x 32 columns]

# %%
presiDis=Presis[Presis.DEPARTAMENTO.isin(yanapayDis.DEPARTAMENTO)]
presiDis
# Out:
#        UBIGEO DEPARTAMENTO             PROVINCIA                DISTRITO  \
# 0       10101     AMAZONAS           CHACHAPOYAS             CHACHAPOYAS
# 1       10101     AMAZONAS           CHACHAPOYAS             CHACHAPOYAS
# 2       10204     AMAZONAS                 BAGUA                EL PARCO
# 3       10512     AMAZONAS  RODRIGUEZ DE MENDOZA            VISTA ALEGRE
# 4       10601     AMAZONAS          CONDORCANQUI                   NIEVA
# ...       ...          ...                   ...                     ...
# 86483  210609   SAN MARTIN            SAN MARTIN               HUIMBAYOC
# 86484  250205      UCAYALI            PADRE ABAD  ALEXANDER VON HUMBOLDT
# 86485  250301      UCAYALI               ATALAYA                RAIMONDI
# 86486  250302      UCAYALI               ATALAYA                TAHUANIA
# 86487  250301      UCAYALI               ATALAYA                RAIMONDI
#
#       TIPO_ELECCION  MESA_DE_VOTACION DESCRIP_ESTADO_ACTA  TIPO_OBSERVACION  \
# 0      PRESIDENCIAL                31       CONTABILIZADA               NaN
# 1      PRESIDENCIAL                54       CONTABILIZADA               NaN
# 2      PRESIDENCIAL               205       CONTABILIZADA               NaN
# 3      PRESIDENCIAL               576       CONTABILIZADA               NaN
# 4      PRESIDENCIAL               585       CONTABILIZADA               NaN
# ...             ...               ...                 ...               ...
# 86483  PRESIDENCIAL            903012       CONTABILIZADA               NaN
# 86484  PRESIDENCIAL             79806       CONTABILIZADA               NaN
# 86485  PRESIDENCIAL             79850       CONTABILIZADA               NaN
# 86486  PRESIDENCIAL             79907       CONTABILIZADA               NaN
# 86487  PRESIDENCIAL             79818       CONTABILIZADA               NaN
#
#        N_CVAS  N_ELEC_HABIL  ...  VOTOS_P13  VOTOS_P14  VOTOS_P15  VOTOS_P16  \
# 0        97.0           300  ...        3.0        NaN        1.0        4.0
# 1       204.0           300  ...       21.0        1.0        2.0       22.0
# 2       224.0           300  ...        7.0        3.0        1.0       54.0
# 3        81.0           247  ...        5.0        1.0        1.0       15.0
# 4       159.0           300  ...        4.0        NaN        NaN       28.0
# ...       ...           ...  ...        ...        ...        ...        ...
# 86483   158.0           188  ...        1.0        1.0        1.0        NaN
# 86484   175.0           238  ...        6.0        1.0        2.0       39.0
# 86485   193.0           300  ...        1.0        NaN        NaN       13.0
# 86486   146.0           300  ...        1.0        1.0        5.0       20.0
# 86487    97.0           291  ...        1.0        NaN        NaN        8.0
#
#        VOTOS_P17  VOTOS_P18  VOTOS_VB  VOTOS_VN  VOTOS_VI  presiEmitidos
# 0            NaN        3.0       NaN      20.0       NaN           97.0
# 1            NaN       30.0      19.0      15.0       NaN          204.0
# 2            NaN       15.0      37.0      14.0       NaN          224.0
# 3            NaN        NaN      28.0       2.0       NaN           81.0
# 4            NaN        2.0      27.0       8.0       NaN          159.0
# ...          ...        ...       ...       ...       ...            ...
# 86483        NaN        3.0      52.0      12.0       NaN          158.0
# 86484        NaN       11.0      55.0       5.0       NaN          175.0
# 86485        1.0        3.0      72.0      12.0       NaN          193.0
# 86486        NaN        3.0      37.0      11.0       NaN          146.0
# 86487        NaN        2.0      47.0       9.0       NaN           97.0
#
# [82202 rows x 32 columns]

# %%
presiDis.columns
# Out:
# Index(['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'TIPO_ELECCION',
#        'MESA_DE_VOTACION', 'DESCRIP_ESTADO_ACTA', 'TIPO_OBSERVACION', 'N_CVAS',
#        'N_ELEC_HABIL', 'VOTOS_P1', 'VOTOS_P2', 'VOTOS_P3', 'VOTOS_P4',
#        'VOTOS_P5', 'VOTOS_P6', 'VOTOS_P7', 'VOTOS_P8', 'VOTOS_P9', 'VOTOS_P10',
#        'VOTOS_P11', 'VOTOS_P12', 'VOTOS_P13', 'VOTOS_P14', 'VOTOS_P15',
#        'VOTOS_P16', 'VOTOS_P17', 'VOTOS_P18', 'VOTOS_VB', 'VOTOS_VN',
#        'VOTOS_VI', 'presiEmitidos'],
#       dtype='object')

# %%
selectPresi=['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'VOTOS_P16', 'presiEmitidos']
presiDis=presiDis.loc[:,selectPresi]
presiDis
# Out:
#        UBIGEO DEPARTAMENTO             PROVINCIA                DISTRITO  \
# 0       10101     AMAZONAS           CHACHAPOYAS             CHACHAPOYAS
# 1       10101     AMAZONAS           CHACHAPOYAS             CHACHAPOYAS
# 2       10204     AMAZONAS                 BAGUA                EL PARCO
# 3       10512     AMAZONAS  RODRIGUEZ DE MENDOZA            VISTA ALEGRE
# 4       10601     AMAZONAS          CONDORCANQUI                   NIEVA
# ...       ...          ...                   ...                     ...
# 86483  210609   SAN MARTIN            SAN MARTIN               HUIMBAYOC
# 86484  250205      UCAYALI            PADRE ABAD  ALEXANDER VON HUMBOLDT
# 86485  250301      UCAYALI               ATALAYA                RAIMONDI
# 86486  250302      UCAYALI               ATALAYA                TAHUANIA
# 86487  250301      UCAYALI               ATALAYA                RAIMONDI
#
#        VOTOS_P16  presiEmitidos
# 0            4.0           97.0
# 1           22.0          204.0
# 2           54.0          224.0
# 3           15.0           81.0
# 4           28.0          159.0
# ...          ...            ...
# 86483        NaN          158.0
# 86484       39.0          175.0
# 86485       13.0          193.0
# 86486       20.0          146.0
# 86487        8.0           97.0
#
# [82202 rows x 6 columns]

# %%
unidades=['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA','DISTRITO']
presiDisPeruLibre=presiDis.groupby(unidades).agg({'presiEmitidos':'sum','VOTOS_P16':'sum'})

# %%
presiDisPeruLibre.reset_index(inplace=True)
presiDisPeruLibre
# Out:
#       UBIGEO DEPARTAMENTO    PROVINCIA     DISTRITO  presiEmitidos  VOTOS_P16
# 0      10101     AMAZONAS  CHACHAPOYAS  CHACHAPOYAS        13619.0     1695.0
# 1      10102     AMAZONAS  CHACHAPOYAS     ASUNCION          114.0       14.0
# 2      10103     AMAZONAS  CHACHAPOYAS       BALSAS          504.0      117.0
# 3      10104     AMAZONAS  CHACHAPOYAS        CHETO          411.0       44.0
# 4      10105     AMAZONAS  CHACHAPOYAS    CHILIQUIN          324.0       41.0
# ...      ...          ...          ...          ...            ...        ...
# 1869  250301      UCAYALI      ATALAYA     RAIMONDI        13165.0     1354.0
# 1870  250302      UCAYALI      ATALAYA     TAHUANIA         2967.0      300.0
# 1871  250303      UCAYALI      ATALAYA        YURUA          393.0       10.0
# 1872  250304      UCAYALI      ATALAYA      SEPAHUA         2657.0      162.0
# 1873  250401      UCAYALI        PURUS        PURUS         1429.0      115.0
#
# [1874 rows x 6 columns]

# %%
CongrePresiYanay=CongreYanay.merge(presiDisPeruLibre,on=theKeys)
CongrePresiYanay
# Out:
#       UBIGEO_x DEPARTAMENTO    PROVINCIA                DISTRITO  PROGRAMADO  \
# 0        10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS       12656
# 1        10102     AMAZONAS  CHACHAPOYAS                ASUNCION         181
# 2        10103     AMAZONAS  CHACHAPOYAS                  BALSAS         848
# 3        10104     AMAZONAS  CHACHAPOYAS                   CHETO         505
# 4        10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN         513
# ...        ...          ...          ...                     ...         ...
# 1869    250302      UCAYALI   PADRE ABAD                 IRAZOLA        7881
# 1870    250303      UCAYALI   PADRE ABAD                CURIMANA        6258
# 1871    250304      UCAYALI   PADRE ABAD                 NESHUYA        4057
# 1872    250305      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT        3396
# 1873    250401      UCAYALI        PURUS                   PURUS        2365
#
#       EJECUTADO  UBIGEO_y  PARTIDO POLITICO NACIONAL PERU LIBRE  TotalEmitido  \
# 0         12126     10101                                 718.0       13427.0
# 1           176     10102                                   5.0         114.0
# 2           790     10103                                  97.0         504.0
# 3           490     10104                                  19.0         411.0
# 4           486     10105                                  18.0         324.0
# ...         ...       ...                                   ...           ...
# 1869       6822    250202                                1149.0        6535.0
# 1870       5567    250203                                 896.0        4142.0
# 1871       3731    250204                                 526.0        3854.0
# 1872       3017    250205                                 457.0        2670.0
# 1873       2065    250401                                  51.0        1282.0
#
#       proporcion  yanaProp  UBIGEO  presiEmitidos  VOTOS_P16
# 0       0.053474  0.958123   10101        13619.0     1695.0
# 1       0.043860  0.972376   10102          114.0       14.0
# 2       0.192460  0.931604   10103          504.0      117.0
# 3       0.046229  0.970297   10104          411.0       44.0
# 4       0.055556  0.947368   10105          324.0       41.0
# ...          ...       ...     ...            ...        ...
# 1869    0.175822  0.865626  250202         6333.0     1659.0
# 1870    0.216321  0.889581  250203         4738.0     1223.0
# 1871    0.136482  0.919645  250204         3658.0      624.0
# 1872    0.171161  0.888398  250205         2670.0      595.0
# 1873    0.039782  0.873150  250401         1429.0      115.0
#
# [1874 rows x 14 columns]

# %%
set(presiDisPeruLibre.PROVINCIA) - set(CongreYanay.PROVINCIA)
# Out:
# set()

# %%
presiDisPeruLibre.PROVINCIA=presiDisPeruLibre.PROVINCIA.str.replace('øø','Ñ')
presiDisPeruLibre.DISTRITO=presiDisPeruLibre.DISTRITO.str.replace('øø','Ñ')

# %%
set(presiDisPeruLibre.DISTRITO) - set(CongreYanay.DISTRITO)
# Out:
# set()

# %%
CongrePresiYanay.columns#.to_csv("CongrePresiYanay.csv",index)
# Out:
# Index(['UBIGEO_x', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'PROGRAMADO',
#        'EJECUTADO', 'PARTIDO POLITICO NACIONAL PERU LIBRE', 'TotalEmitido',
#        'proporcion', 'yanaProp', 'UBIGEO', 'presiEmitidos', 'VOTOS_P16'],
#       dtype='object')

# %%
CongrePresiYanay[CongrePresiYanay.UBIGEO_y!=CongrePresiYanay.UBIGEO]
CongrePresiYanay.drop(columns='UBIGEO_y',inplace=True)
CongrePresiYanay
# Out:
#       UBIGEO_x DEPARTAMENTO    PROVINCIA                DISTRITO  PROGRAMADO  \
# 0        10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS       12656
# 1        10102     AMAZONAS  CHACHAPOYAS                ASUNCION         181
# 2        10103     AMAZONAS  CHACHAPOYAS                  BALSAS         848
# 3        10104     AMAZONAS  CHACHAPOYAS                   CHETO         505
# 4        10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN         513
# ...        ...          ...          ...                     ...         ...
# 1869    250302      UCAYALI   PADRE ABAD                 IRAZOLA        7881
# 1870    250303      UCAYALI   PADRE ABAD                CURIMANA        6258
# 1871    250304      UCAYALI   PADRE ABAD                 NESHUYA        4057
# 1872    250305      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT        3396
# 1873    250401      UCAYALI        PURUS                   PURUS        2365
#
#       EJECUTADO  PARTIDO POLITICO NACIONAL PERU LIBRE  TotalEmitido  \
# 0         12126                                 718.0       13427.0
# 1           176                                   5.0         114.0
# 2           790                                  97.0         504.0
# 3           490                                  19.0         411.0
# 4           486                                  18.0         324.0
# ...         ...                                   ...           ...
# 1869       6822                                1149.0        6535.0
# 1870       5567                                 896.0        4142.0
# 1871       3731                                 526.0        3854.0
# 1872       3017                                 457.0        2670.0
# 1873       2065                                  51.0        1282.0
#
#       proporcion  yanaProp  UBIGEO  presiEmitidos  VOTOS_P16
# 0       0.053474  0.958123   10101        13619.0     1695.0
# 1       0.043860  0.972376   10102          114.0       14.0
# 2       0.192460  0.931604   10103          504.0      117.0
# 3       0.046229  0.970297   10104          411.0       44.0
# 4       0.055556  0.947368   10105          324.0       41.0
# ...          ...       ...     ...            ...        ...
# 1869    0.175822  0.865626  250202         6333.0     1659.0
# 1870    0.216321  0.889581  250203         4738.0     1223.0
# 1871    0.136482  0.919645  250204         3658.0      624.0
# 1872    0.171161  0.888398  250205         2670.0      595.0
# 1873    0.039782  0.873150  250401         1429.0      115.0
#
# [1874 rows x 13 columns]

# %%
olds=['UBIGEO_x','PROGRAMADO','EJECUTADO','PARTIDO POLITICO NACIONAL PERU LIBRE','TotalEmitido','proporcion','VOTOS_P16']
news=['UBIGEO_yana','programado_yana','ejecutado_yana','PeruLibre_congre',"congreEmitidos","proporcion_congre",'PeruLibre_presi']
mapChanges={old:new for old,new in zip(olds,news)}
CongrePresiYanay.rename(columns=mapChanges,inplace=True)
CongrePresiYanay
# Out:
#       UBIGEO_yana DEPARTAMENTO    PROVINCIA                DISTRITO  \
# 0           10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1           10102     AMAZONAS  CHACHAPOYAS                ASUNCION
# 2           10103     AMAZONAS  CHACHAPOYAS                  BALSAS
# 3           10104     AMAZONAS  CHACHAPOYAS                   CHETO
# 4           10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...           ...          ...          ...                     ...
# 1869       250302      UCAYALI   PADRE ABAD                 IRAZOLA
# 1870       250303      UCAYALI   PADRE ABAD                CURIMANA
# 1871       250304      UCAYALI   PADRE ABAD                 NESHUYA
# 1872       250305      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1873       250401      UCAYALI        PURUS                   PURUS
#
#       programado_yana  ejecutado_yana  PeruLibre_congre  congreEmitidos  \
# 0               12656           12126             718.0         13427.0
# 1                 181             176               5.0           114.0
# 2                 848             790              97.0           504.0
# 3                 505             490              19.0           411.0
# 4                 513             486              18.0           324.0
# ...               ...             ...               ...             ...
# 1869             7881            6822            1149.0          6535.0
# 1870             6258            5567             896.0          4142.0
# 1871             4057            3731             526.0          3854.0
# 1872             3396            3017             457.0          2670.0
# 1873             2365            2065              51.0          1282.0
#
#       proporcion_congre  yanaProp  UBIGEO  presiEmitidos  PeruLibre_presi
# 0              0.053474  0.958123   10101        13619.0           1695.0
# 1              0.043860  0.972376   10102          114.0             14.0
# 2              0.192460  0.931604   10103          504.0            117.0
# 3              0.046229  0.970297   10104          411.0             44.0
# 4              0.055556  0.947368   10105          324.0             41.0
# ...                 ...       ...     ...            ...              ...
# 1869           0.175822  0.865626  250202         6333.0           1659.0
# 1870           0.216321  0.889581  250203         4738.0           1223.0
# 1871           0.136482  0.919645  250204         3658.0            624.0
# 1872           0.171161  0.888398  250205         2670.0            595.0
# 1873           0.039782  0.873150  250401         1429.0            115.0
#
# [1874 rows x 13 columns]

# %%
orderCols=['UBIGEO_yana', 'UBIGEO','DEPARTAMENTO', 'PROVINCIA', 'DISTRITO',
       'programado_yana', 'ejecutado_yana','yanaProp', 'PeruLibre_congre',
       'congreEmitidos', 'proporcion_congre', 'PeruLibre_presi','presiEmitidos']
CongrePresiYanay=CongrePresiYanay.loc[:,orderCols]
CongrePresiYanay
# Out:
#       UBIGEO_yana  UBIGEO DEPARTAMENTO    PROVINCIA                DISTRITO  \
# 0           10101   10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1           10102   10102     AMAZONAS  CHACHAPOYAS                ASUNCION
# 2           10103   10103     AMAZONAS  CHACHAPOYAS                  BALSAS
# 3           10104   10104     AMAZONAS  CHACHAPOYAS                   CHETO
# 4           10105   10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...           ...     ...          ...          ...                     ...
# 1869       250302  250202      UCAYALI   PADRE ABAD                 IRAZOLA
# 1870       250303  250203      UCAYALI   PADRE ABAD                CURIMANA
# 1871       250304  250204      UCAYALI   PADRE ABAD                 NESHUYA
# 1872       250305  250205      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1873       250401  250401      UCAYALI        PURUS                   PURUS
#
#       programado_yana  ejecutado_yana  yanaProp  PeruLibre_congre  \
# 0               12656           12126  0.958123             718.0
# 1                 181             176  0.972376               5.0
# 2                 848             790  0.931604              97.0
# 3                 505             490  0.970297              19.0
# 4                 513             486  0.947368              18.0
# ...               ...             ...       ...               ...
# 1869             7881            6822  0.865626            1149.0
# 1870             6258            5567  0.889581             896.0
# 1871             4057            3731  0.919645             526.0
# 1872             3396            3017  0.888398             457.0
# 1873             2365            2065  0.873150              51.0
#
#       congreEmitidos  proporcion_congre  PeruLibre_presi  presiEmitidos
# 0            13427.0           0.053474           1695.0        13619.0
# 1              114.0           0.043860             14.0          114.0
# 2              504.0           0.192460            117.0          504.0
# 3              411.0           0.046229             44.0          411.0
# 4              324.0           0.055556             41.0          324.0
# ...              ...                ...              ...            ...
# 1869          6535.0           0.175822           1659.0         6333.0
# 1870          4142.0           0.216321           1223.0         4738.0
# 1871          3854.0           0.136482            624.0         3658.0
# 1872          2670.0           0.171161            595.0         2670.0
# 1873          1282.0           0.039782            115.0         1429.0
#
# [1874 rows x 13 columns]

# %%
CongrePresiYanay['proporcion_presi']=CongrePresiYanay.PeruLibre_presi/CongrePresiYanay.presiEmitidos
CongrePresiYanay
# Out:
#       UBIGEO_yana  UBIGEO DEPARTAMENTO    PROVINCIA                DISTRITO  \
# 0           10101   10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1           10102   10102     AMAZONAS  CHACHAPOYAS                ASUNCION
# 2           10103   10103     AMAZONAS  CHACHAPOYAS                  BALSAS
# 3           10104   10104     AMAZONAS  CHACHAPOYAS                   CHETO
# 4           10105   10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...           ...     ...          ...          ...                     ...
# 1869       250302  250202      UCAYALI   PADRE ABAD                 IRAZOLA
# 1870       250303  250203      UCAYALI   PADRE ABAD                CURIMANA
# 1871       250304  250204      UCAYALI   PADRE ABAD                 NESHUYA
# 1872       250305  250205      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1873       250401  250401      UCAYALI        PURUS                   PURUS
#
#       programado_yana  ejecutado_yana  yanaProp  PeruLibre_congre  \
# 0               12656           12126  0.958123             718.0
# 1                 181             176  0.972376               5.0
# 2                 848             790  0.931604              97.0
# 3                 505             490  0.970297              19.0
# 4                 513             486  0.947368              18.0
# ...               ...             ...       ...               ...
# 1869             7881            6822  0.865626            1149.0
# 1870             6258            5567  0.889581             896.0
# 1871             4057            3731  0.919645             526.0
# 1872             3396            3017  0.888398             457.0
# 1873             2365            2065  0.873150              51.0
#
#       congreEmitidos  proporcion_congre  PeruLibre_presi  presiEmitidos  \
# 0            13427.0           0.053474           1695.0        13619.0
# 1              114.0           0.043860             14.0          114.0
# 2              504.0           0.192460            117.0          504.0
# 3              411.0           0.046229             44.0          411.0
# 4              324.0           0.055556             41.0          324.0
# ...              ...                ...              ...            ...
# 1869          6535.0           0.175822           1659.0         6333.0
# 1870          4142.0           0.216321           1223.0         4738.0
# 1871          3854.0           0.136482            624.0         3658.0
# 1872          2670.0           0.171161            595.0         2670.0
# 1873          1282.0           0.039782            115.0         1429.0
#
#       proporcion_presi
# 0             0.124458
# 1             0.122807
# 2             0.232143
# 3             0.107056
# 4             0.126543
# ...                ...
# 1869          0.261961
# 1870          0.258126
# 1871          0.170585
# 1872          0.222846
# 1873          0.080476
#
# [1874 rows x 14 columns]

# %%
CongrePresiYanay.to_csv('CongrePresiYanay.csv',index=False)

# %%
b600=pd.read_excel("BONO 600 - DISTRITAL.xlsx",4)

# %%
b600.describe()
# Out:
#              IDBONO         UBIGEO  IDTIPO_ABONO   HOGARES_PROG   HOGARES_EJEC
# count  18910.000000   18910.000000  18910.000000   18910.000000   18910.000000
# mean       7.500000  106808.704918      2.000000     249.734532     234.035378
# std        0.500013   67142.095551      1.414251    2456.476298    2395.717735
# min        7.000000   10101.000000      0.000000       0.000000       0.000000
# 25%        7.000000   50403.000000      1.000000       0.000000       0.000000
# 50%        7.500000  100316.000000      2.000000       0.000000       0.000000
# 75%        8.000000  150806.000000      3.000000       0.000000       0.000000
# max        8.000000  250401.000000      4.000000  153702.000000  153702.000000

# %%
b600Sum=b600.groupby(['UBIGEO', 'DEPARTAMENTO', 'PROVINCIA','DISTRITO']).agg({'HOGARES_PROG': 'sum','HOGARES_EJEC':'sum'})
b600Sum.reset_index(inplace=True)

# %%
onlyb600=list(set(b600Sum.DISTRITO) - set(CongreYanay.DISTRITO))
onlyYana=list(set(CongreYanay.DISTRITO) - set(b600Sum.DISTRITO))

# %%
onlyb600
# Out:
# ['MILPUC',
#  'LAMBRAS',
#  'MAZAMARI/PANGOA',
#  'UNION ASHANINKA',
#  'HUAYLLAY GRANDE',
#  'RIO MAGDALENA',
#  'SANTA CRUZ DE TOLEDO',
#  'BOQUERON',
#  'CASPISAPA',
#  'GAMARRA',
#  'PATIBAMBA',
#  'KUMPIRUSHIATO',
#  'TOMAY KICHWA',
#  'CAPAZO',
#  'CARMEN DE LA LEGUA REYNOSO',
#  'RAYMONDI',
#  'HUIPOCA',
#  'MANITEA',
#  'SAN JUAN DE ISCOS',
#  'SANTA RITA DE SIGUAS',
#  'UNION PROGRESO',
#  'ESTIQUE-PAMPA',
#  'CIELO PUNCO',
#  'AHUAYRO',
#  'HUAYA',
#  'QUISQUI (KICHKI)',
#  'RINCONADA LLICUAR',
#  'PUTIS']

# %%
from thefuzz import process

changesb600={dis: process.extractOne(dis, onlyYana)[0] for dis in sorted(onlyb600) if process.extractOne(dis, onlyYana)[1]>70}
changesb600#, len(changesb600)
# Out:
# {'CAPAZO': 'CAPASO',
#  'CARMEN DE LA LEGUA REYNOSO': 'CARMEN DE LA LEGUA-REYNOSO',
#  'CASPISAPA': 'CASPIZAPA',
#  'ESTIQUE-PAMPA': 'ESTIQUE PAMPA',
#  'GAMARRA': 'MARISCAL GAMARRA',
#  'HUAYA': 'HUALLA',
#  'HUAYLLAY GRANDE': 'HUALLAY-GRANDE',
#  'MILPUC': 'MILPUCC',
#  'QUISQUI (KICHKI)': 'QUISQUI',
#  'RAYMONDI': 'RAIMONDI',
#  'RINCONADA LLICUAR': 'RINCONADA-LLICUAR',
#  'SAN JUAN DE ISCOS': 'SAN JUAN DE YSCOS',
#  'SANTA CRUZ DE TOLEDO': 'SANTA CRUZ DE TOLED',
#  'SANTA RITA DE SIGUAS': 'SANTA RITA DE SIHUAS',
#  'TOMAY KICHWA': 'TOMAY-KICHWA'}

# %%
b600Sum.DISTRITO.replace(changesb600,inplace=True)
b600Sum
# Out:
#       UBIGEO DEPARTAMENTO    PROVINCIA                DISTRITO  HOGARES_PROG  \
# 0      10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS             0
# 1      10102     AMAZONAS  CHACHAPOYAS                ASUNCION             0
# 2      10103     AMAZONAS  CHACHAPOYAS                  BALSAS             0
# 3      10104     AMAZONAS  CHACHAPOYAS                   CHETO             0
# 4      10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN             0
# ...      ...          ...          ...                     ...           ...
# 1886  250304      UCAYALI   PADRE ABAD                 NESHUYA             0
# 1887  250305      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT             0
# 1888  250306      UCAYALI   PADRE ABAD                 HUIPOCA             0
# 1889  250307      UCAYALI   PADRE ABAD                BOQUERON             0
# 1890  250401      UCAYALI        PURUS                   PURUS             0
#
#       HOGARES_EJEC
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 1886             0
# 1887             0
# 1888             0
# 1889             0
# 1890             0
#
# [1891 rows x 6 columns]

# %%
onlyb600=list(set(b600Sum.DISTRITO) - set(CongreYanay.DISTRITO))
onlyYana=list(set(CongreYanay.DISTRITO) - set(b600Sum.DISTRITO))

# %%
onlyb600
# Out:
# ['HUIPOCA',
#  'LAMBRAS',
#  'MAZAMARI/PANGOA',
#  'MANITEA',
#  'UNION ASHANINKA',
#  'PATIBAMBA',
#  'UNION PROGRESO',
#  'KUMPIRUSHIATO',
#  'CIELO PUNCO',
#  'RIO MAGDALENA',
#  'AHUAYRO',
#  'BOQUERON',
#  'PUTIS']

# %%
onlyb600P=list(set(b600Sum.PROVINCIA) - set(CongreYanay.PROVINCIA))
onlyYanaP=list(set(CongreYanay.PROVINCIA) - set(b600Sum.PROVINCIA))

# %%
onlyb600P
# Out:
# ['ANTONIO RAYMONDI']

# %%
b600Sum['PROVINCIA']=b600Sum.PROVINCIA.str.replace(pat='ANTONIO RAYMONDI',repl='ANTONIO RAIMONDI',regex=False)

# %%
CongrePresiYanay
# Out:
#       UBIGEO_yana  UBIGEO DEPARTAMENTO    PROVINCIA                DISTRITO  \
# 0           10101   10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1           10102   10102     AMAZONAS  CHACHAPOYAS                ASUNCION
# 2           10103   10103     AMAZONAS  CHACHAPOYAS                  BALSAS
# 3           10104   10104     AMAZONAS  CHACHAPOYAS                   CHETO
# 4           10105   10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...           ...     ...          ...          ...                     ...
# 1869       250302  250202      UCAYALI   PADRE ABAD                 IRAZOLA
# 1870       250303  250203      UCAYALI   PADRE ABAD                CURIMANA
# 1871       250304  250204      UCAYALI   PADRE ABAD                 NESHUYA
# 1872       250305  250205      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1873       250401  250401      UCAYALI        PURUS                   PURUS
#
#       programado_yana  ejecutado_yana  yanaProp  PeruLibre_congre  \
# 0               12656           12126  0.958123             718.0
# 1                 181             176  0.972376               5.0
# 2                 848             790  0.931604              97.0
# 3                 505             490  0.970297              19.0
# 4                 513             486  0.947368              18.0
# ...               ...             ...       ...               ...
# 1869             7881            6822  0.865626            1149.0
# 1870             6258            5567  0.889581             896.0
# 1871             4057            3731  0.919645             526.0
# 1872             3396            3017  0.888398             457.0
# 1873             2365            2065  0.873150              51.0
#
#       congreEmitidos  proporcion_congre  PeruLibre_presi  presiEmitidos  \
# 0            13427.0           0.053474           1695.0        13619.0
# 1              114.0           0.043860             14.0          114.0
# 2              504.0           0.192460            117.0          504.0
# 3              411.0           0.046229             44.0          411.0
# 4              324.0           0.055556             41.0          324.0
# ...              ...                ...              ...            ...
# 1869          6535.0           0.175822           1659.0         6333.0
# 1870          4142.0           0.216321           1223.0         4738.0
# 1871          3854.0           0.136482            624.0         3658.0
# 1872          2670.0           0.171161            595.0         2670.0
# 1873          1282.0           0.039782            115.0         1429.0
#
#       proporcion_presi
# 0             0.124458
# 1             0.122807
# 2             0.232143
# 3             0.107056
# 4             0.126543
# ...                ...
# 1869          0.261961
# 1870          0.258126
# 1871          0.170585
# 1872          0.222846
# 1873          0.080476
#
# [1874 rows x 14 columns]

# %%
theKeys=['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO']
b600Sum.drop(columns=["UBIGEO"],inplace=True)
CongrePresiYanay600=CongrePresiYanay.merge(b600Sum,on=theKeys)
mapren={'HOGARES_PROG':'programado_b600','HOGARES_EJEC':'ejecutado_b600'}
CongrePresiYanay600.rename(columns=mapren,inplace=True)
CongrePresiYanay600
# Out:
#       UBIGEO_yana  UBIGEO DEPARTAMENTO    PROVINCIA                DISTRITO  \
# 0           10101   10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1           10102   10102     AMAZONAS  CHACHAPOYAS                ASUNCION
# 2           10103   10103     AMAZONAS  CHACHAPOYAS                  BALSAS
# 3           10104   10104     AMAZONAS  CHACHAPOYAS                   CHETO
# 4           10105   10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...           ...     ...          ...          ...                     ...
# 1869       250302  250202      UCAYALI   PADRE ABAD                 IRAZOLA
# 1870       250303  250203      UCAYALI   PADRE ABAD                CURIMANA
# 1871       250304  250204      UCAYALI   PADRE ABAD                 NESHUYA
# 1872       250305  250205      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1873       250401  250401      UCAYALI        PURUS                   PURUS
#
#       programado_yana  ejecutado_yana  yanaProp  PeruLibre_congre  \
# 0               12656           12126  0.958123             718.0
# 1                 181             176  0.972376               5.0
# 2                 848             790  0.931604              97.0
# 3                 505             490  0.970297              19.0
# 4                 513             486  0.947368              18.0
# ...               ...             ...       ...               ...
# 1869             7881            6822  0.865626            1149.0
# 1870             6258            5567  0.889581             896.0
# 1871             4057            3731  0.919645             526.0
# 1872             3396            3017  0.888398             457.0
# 1873             2365            2065  0.873150              51.0
#
#       congreEmitidos  proporcion_congre  PeruLibre_presi  presiEmitidos  \
# 0            13427.0           0.053474           1695.0        13619.0
# 1              114.0           0.043860             14.0          114.0
# 2              504.0           0.192460            117.0          504.0
# 3              411.0           0.046229             44.0          411.0
# 4              324.0           0.055556             41.0          324.0
# ...              ...                ...              ...            ...
# 1869          6535.0           0.175822           1659.0         6333.0
# 1870          4142.0           0.216321           1223.0         4738.0
# 1871          3854.0           0.136482            624.0         3658.0
# 1872          2670.0           0.171161            595.0         2670.0
# 1873          1282.0           0.039782            115.0         1429.0
#
#       proporcion_presi  programado_b600  ejecutado_b600
# 0             0.124458                0               0
# 1             0.122807                0               0
# 2             0.232143                0               0
# 3             0.107056                0               0
# 4             0.126543                0               0
# ...                ...              ...             ...
# 1869          0.261961                0               0
# 1870          0.258126                0               0
# 1871          0.170585                0               0
# 1872          0.222846                0               0
# 1873          0.080476                0               0
#
# [1874 rows x 16 columns]

# %%
CongrePresiYanay600.to_csv("CongrePresiYanay600.csv",index=False)

# %%
ceplan=pd.read_excel("Datos-para-el-planeamiento-estrategico.xlsx",3,skiprows=8)
ceplan.head(20)
# Out:
#       Unnamed: 0                         Ubigeo  \
# 0       Nacional                       NACIONAL
# 1   Nacional_esp  NACIONAL SIN LA PROV. DE LIMA
# 2         Región                         150000
# 3           Zona                     ZONA NORTE
# 4         Región                         010000
# 5      Provincia                         010200
# 6       Distrito                         010202
# 7       Distrito                         010201
# 8       Distrito                         010203
# 9       Distrito                         010204
# 10      Distrito                         010205
# 11      Distrito                         010206
# 12     Provincia                         010300
# 13      Distrito                         010302
# 14      Distrito                         010303
# 15      Distrito                         010304
# 16      Distrito                         010305
# 17      Distrito                         010306
# 18      Distrito                         010307
# 19      Distrito                         010301
#
#    Región /\nProvincia /\nDistrito Población total\n(2007)\n1a/  \
# 0                              NaN                     28481901
# 1                              NaN                     20620156
# 2                             LIMA                      8730820
# 3                              NaN                      8367388
# 4                         AMAZONAS                       406087
# 5                            BAGUA                        77637
# 6                         ARAMANGO                        12449
# 7                            BAGUA                        25984
# 8                         COPALLÍN                         6736
# 9                         EL PARCO                         1376
# 10                           IMAZA                        23109
# 11                      LA PECA a/                         7983
# 12                         BONGARÁ                        29552
# 13                      CHISQUILLA                          369
# 14                         CHURUJA                          302
# 15                         COROSHA                          762
# 16                         CUISPES                          863
# 17                         FLORIDA                         6641
# 18                           JAZAN                         8981
# 19                        JUMBILLA                         1691
#
#     Población total\n(2017)\n1a/  Población total\n(2020)\n1b/  \
# 0                     31237385.0                    34393444.0
# 1                     22075063.0                    24188630.0
# 2                     10135009.0                    11261067.0
# 3                      8987709.0                     9962022.0
# 4                       417365.0                      472993.0
# 5                        82193.0                       98110.0
# 6                        10487.0                       12396.0
# 7                        28836.0                       27423.0
# 8                         4972.0                        5694.0
# 9                         1293.0                        1719.0
# 10                       29852.0                       40964.0
# 11                        6753.0                        9914.0
# 12                       27085.0                       29335.0
# 13                         324.0                         526.0
# 14                         297.0                         382.0
# 15                         805.0                         991.0
# 16                         708.0                         827.0
# 17                        6395.0                        6480.0
# 18                        8059.0                        8391.0
# 19                        1385.0                        1213.0
#
#     Población de niños menores de un año\n(CENSO 2017)\n1a/  \
# 0                                            493495.0
# 1                                            371675.0
# 2                                            137218.0
# 3                                            162076.0
# 4                                              8043.0
# 5                                              1636.0
# 6                                               196.0
# 7                                               442.0
# 8                                                69.0
# 9                                                18.0
# 10                                              799.0
# 11                                              112.0
# 12                                              397.0
# 13                                                7.0
# 14                                                3.0
# 15                                               16.0
# 16                                                9.0
# 17                                              108.0
# 18                                               99.0
# 19                                               17.0
#
#     Población mayor de 80 años \n(2020)\n1b/  \
# 0                                   628342.0
# 1                                   434258.0
# 2                                   217672.0
# 3                                   171114.0
# 4                                     7743.0
# 5                                     1217.0
# 6                                      192.0
# 7                                      327.0
# 8                                      117.0
# 9                                       39.0
# 10                                     224.0
# 11                                     318.0
# 12                                     655.0
# 13                                       9.0
# 14                                      18.0
# 15                                      18.0
# 16                                      26.0
# 17                                     135.0
# 18                                     221.0
# 19                                      32.0
#
#    Población con Discapacidad\n(2020)\n1c/ Superficie (km2) \n2/  ...  \
# 0                                   297030            1280172.28  ...
# 1                                   217586            1277557.12  ...
# 2                                    88625              34823.52  ...
# 3                                    84289             572940.33  ...
# 4                                     7826              39249.13  ...
# 5                                     1586               5652.72  ...
# 6                                      191                809.07  ...
# 7                                      513                150.99  ...
# 8                                      129                 99.05  ...
# 9                                       19                 18.48  ...
# 10                                     358               4430.84  ...
# 11                                     376                144.29  ...
# 12                                     398               2869.65  ...
# 13                                      15                174.96  ...
# 14                                       7                 33.34  ...
# 15                                      11                 45.67  ...
# 16                                       2                110.72  ...
# 17                                      42                203.22  ...
# 18                                     145                 88.83  ...
# 19                                       8                154.18  ...
#
#    Índice de Desarrollo Humano -IDH\n(2019)\n15/  \
# 0                                       0.585764
# 1                                              -
# 2                                       0.707336
# 3                                              -
# 4                                       0.417736
# 5                                       0.461036
# 6                                       0.361182
# 7                                       0.584063
# 8                                       0.467245
# 9                                       0.489049
# 10                                      0.298089
# 11                                      0.490584
# 12                                      0.412895
# 13                                      0.474975
# 14                                      0.515914
# 15                                      0.395898
# 16                                      0.299445
# 17                                      0.359324
# 18                                      0.511258
# 19                                      0.451394
#
#    Porcentaje de la población en pobreza total\n16a/  \
# 0                                          30.100000
# 1                                          31.724256
# 2                                          26.250000
# 3                                          31.834415
# 4                                          32.950000
# 5                                          34.843027
# 6                                          38.525807
# 7                                          16.212835
# 8                                          24.530258
# 9                                          35.249588
# 10                                         53.949690
# 11                                         34.761666
# 12                                         33.240504
# 13                                         42.241830
# 14                                         20.786950
# 15                                         54.796368
# 16                                         45.831589
# 17                                         33.682214
# 18                                         22.712901
# 19                                         29.547678
#
#     Pobreza total: Número de habitantes en situación de pobreza\n\n16b/  \
# 0                                        1.035243e+07
# 1                                        7.673663e+06
# 2                                        2.956030e+06
# 3                                        3.171351e+06
# 4                                        1.558512e+05
# 5                                        3.418449e+04
# 6                                        4.775659e+03
# 7                                        4.446046e+03
# 8                                        1.396753e+03
# 9                                        6.059404e+02
# 10                                       2.209995e+04
# 11                                       3.446272e+03
# 12                                       9.751102e+03
# 13                                       2.221920e+02
# 14                                       7.940615e+01
# 15                                       5.430320e+02
# 16                                       3.790272e+02
# 17                                       2.182607e+03
# 18                                       1.905840e+03
# 19                                       3.584133e+02
#
#     Porcentaje de la población en pobreza extrema \n17a/  \
# 0                                            5.100000
# 1                                            5.964864
# 2                                            3.050000
# 3                                            5.864900
# 4                                            7.300000
# 5                                           23.068140
# 6                                           19.270750
# 7                                            4.467983
# 8                                           11.243630
# 9                                           12.159050
# 10                                          48.888840
# 11                                          21.799500
# 12                                          10.740246
# 13                                          22.561790
# 14                                           1.867667
# 15                                          24.577630
# 16                                          12.790520
# 17                                           6.342470
# 18                                          13.668210
# 19                                           5.129210
#
#     Pobreza extrema: Número de habitantes en situación de pobreza extrema \n17b/  \
# 0                                        1.754066e+06
# 1                                        1.442819e+06
# 2                                        3.434625e+05
# 3                                        5.842626e+05
# 4                                        3.452849e+04
# 5                                        2.263215e+04
# 6                                        2.388802e+03
# 7                                        1.225255e+03
# 8                                        6.402123e+02
# 9                                        2.090141e+02
# 10                                       2.002682e+04
# 11                                       2.161202e+03
# 12                                       3.150651e+03
# 13                                       1.186750e+02
# 14                                       7.134488e+00
# 15                                       2.435643e+02
# 16                                       1.057776e+02
# 17                                       4.109921e+02
# 18                                       1.146900e+03
# 19                                       6.221732e+01
#
#    Población Ocupada\n(2007) \n18/  Población Ocupada\n(2017 )\n18/  \
# 0                         10251272                     1.314957e+07
# 1                          6964502                     8.705205e+06
# 2                          3625326                     4.873073e+06
# 3                          2690762                     3.324782e+06
# 4                           124320                     1.427014e+05
# 5                            24239                     2.688646e+04
# 6                             4019                     3.569083e+03
# 7                             (**)                     1.191331e+04
# 8                             2307                     1.700876e+03
# 9                              417                     3.702573e+02
# 10                            6074                     6.894086e+03
# 11                            (**)                     2.438856e+03
# 12                           10037                     1.121259e+04
# 13                             157                     1.469728e+02
# 14                             106                     1.233129e+02
# 15                             227                     3.425056e+02
# 16                             329                     2.979671e+02
# 17                            2123                     2.468067e+03
# 18                            3022                     3.727907e+03
# 19                             599                     6.463395e+02
#
#    Devengado per cápita en soles (2020) - Actividad\n19/  \
# 0                                         4520.201693
# 1                                         3330.091783
# 2                                         6923.735936
# 3                                         2947.760521
# 4                                         3919.830013
# 5                                         4747.486136
# 6                                          273.789848
# 7                                         3978.526911
# 8                                          447.754064
# 9                                          509.347243
# 10                                        2693.190003
# 11                                         768.876417
# 12                                         818.668763
# 13                                        1778.323821
# 14                                        1866.534346
# 15                                        1039.656024
# 16                                        1046.435091
# 17                                         299.531593
# 18                                         400.064087
# 19                                        2814.439060
#
#    Devengado per cápita en soles (2020) - Inversión\n19/  \
# 0                                          770.969110
# 1                                          897.070679
# 2                                          488.735054
# 3                                          821.040898
# 4                                         1561.378837
# 5                                         1050.076689
# 6                                          372.794589
# 7                                         1089.854262
# 8                                         4689.310687
# 9                                         1474.730733
# 10                                         220.047251
# 11                                         142.695759
# 12                                        1288.069595
# 13                                         178.424905
# 14                                        7316.193246
# 15                                         577.468274
# 16                                         215.142684
# 17                                        1969.657198
# 18                                         367.563588
# 19                                        3789.357890
#
#     Devengado per cápita en soles (2020) - Total\n19/
# 0                                         5291.170803
# 1                                         4227.162462
# 2                                         7412.470989
# 3                                         3768.801420
# 4                                         5481.208850
# 5                                         5797.562825
# 6                                          646.584438
# 7                                         5068.381173
# 8                                         5137.064751
# 9                                         1984.077976
# 10                                        2913.237254
# 11                                         911.572176
# 12                                        2106.738358
# 13                                        1956.748726
# 14                                        9182.727592
# 15                                        1617.124299
# 16                                        1261.577775
# 17                                        2269.188790
# 18                                         767.627675
# 19                                        6603.796950
#
# [20 rows x 48 columns]

# %%
ceplan.columns
# Out:
# Index(['Unnamed: 0', 'Ubigeo', 'Región /\nProvincia /\nDistrito',
#        'Población total\n(2007)\n1a/', 'Población total\n(2017)\n1a/',
#        'Población total\n(2020)\n1b/',
#        'Población de niños menores de un año\n(CENSO 2017)\n1a/',
#        'Población mayor de 80 años \n(2020)\n1b/',
#        'Población con Discapacidad\n(2020)\n1c/', 'Superficie (km2) \n2/',
#        'Densidad\n(2020)', 'Capital legal \n3/', 'Altitud (msnm)\n 3/',
#        'Latitud\nsur\n 3/', 'Longitud oeste\n 3/',
#        'Tipología de distrito según SDOT\n4/',
#        'Centro  Fucional de Organización Territorial\n4a/',
#        'Número de Provincias 3/', 'Número  de Distritos \n3/',
#        'Número de Centros Poblados\n3/', 'País fronterizo',
#        'Población de niños menores de un año\n(CENSO 2017)\n1a/.1',
#        'Número anual de nacidos vivos según distrito de residencia habitual de la madre (2020)\n5/',
#        'Número anual de nacidos vivos con bajo peso según distrito de residencia habitual de la madre (2020)\n5/',
#        'Porcentaje de nacidos vivos con bajo peso al nacer (2020)\n5/ 6/',
#        'Total',
#        'Número  de niños menores de un año con DNI emitido hasta los 30 días de nacido (2020)\n7/',
#        'Porcentaje de niños menores de un año con DNI emitido hasta los 30 días de nacido (al 2021)\n7/',
#        'Índice de Vulnerabilidad a la Inseguridad Alimentaria (IVIA) \n(2018)\n8/',
#        'Porcentaje de desnutrición crónica\n (Niños menores de 5 años) \n(2020)\n9/',
#        'Porcentaje de anemia\n(Niños entre 6 y 35 meses) (2020)\n9/',
#        'Porcentaje de personas de 15 años y más con exceso de peso\n(2020)\n10/',
#        'Distritos dentro de Meta 4\n11/',
#        'Índice de Densidad del Estado -IDE\n(2017)\n12/',
#        'Centros de salud mental comunal\n(al 2021)\n13/',
#        'Cámara de comercio\n13a/', 'Sedes del SENATI\n(al 2021)\n13b/',
#        'Mercados de abastos (2016)\n14/',
#        'Índice de Desarrollo Humano -IDH\n(2019)\n15/',
#        'Porcentaje de la población en pobreza total\n16a/',
#        'Pobreza total: Número de habitantes en situación de pobreza\n\n16b/',
#        'Porcentaje de la población en pobreza extrema \n17a/',
#        'Pobreza extrema: Número de habitantes en situación de pobreza extrema \n17b/',
#        'Población Ocupada\n(2007) \n18/', 'Población Ocupada\n(2017 )\n18/',
#        'Devengado per cápita en soles (2020) - Actividad\n19/',
#        'Devengado per cápita en soles (2020) - Inversión\n19/',
#        'Devengado per cápita en soles (2020) - Total\n19/'],
#       dtype='object')

# %%
selectceplan=['Unnamed: 0', 
              'Ubigeo', 
              'Región /\nProvincia /\nDistrito',
              'Población total\n(2020)\n1b/',
              'Población con Discapacidad\n(2020)\n1c/',
              'Superficie (km2) \n2/',
              'Densidad\n(2020)', 
              'Altitud (msnm)\n 3/',
              'Latitud\nsur\n 3/', 
              'Longitud oeste\n 3/',
              'Número de Centros Poblados\n3/',
              'Porcentaje de desnutrición crónica\n (Niños menores de 5 años) \n(2020)\n9/',
              'Pobreza total: Número de habitantes en situación de pobreza\n\n16b/',
              'Pobreza extrema: Número de habitantes en situación de pobreza extrema \n17b/',
            'Porcentaje de la población en pobreza extrema \n17a/']
ceplan=ceplan[selectceplan]
ceplan
# Out:
#         Unnamed: 0                         Ubigeo  \
# 0         Nacional                       NACIONAL
# 1     Nacional_esp  NACIONAL SIN LA PROV. DE LIMA
# 2           Región                         150000
# 3             Zona                     ZONA NORTE
# 4           Región                         010000
# ...            ...                            ...
# 2125           NaN                            NaN
# 2126           NaN                            NaN
# 2127           NaN                            NaN
# 2128           NaN                            NaN
# 2129           NaN                            NaN
#
#      Región /\nProvincia /\nDistrito  Población total\n(2020)\n1b/  \
# 0                                NaN                    34393444.0
# 1                                NaN                    24188630.0
# 2                               LIMA                    11261067.0
# 3                                NaN                     9962022.0
# 4                           AMAZONAS                      472993.0
# ...                              ...                           ...
# 2125                             NaN                           NaN
# 2126                        ZONA SUR                           NaN
# 2127                    DEPARTAMENTO                           NaN
# 2128                       PROVINCIA                           NaN
# 2129                        DISTRITO                           NaN
#
#      Población con Discapacidad\n(2020)\n1c/ Superficie (km2) \n2/  \
# 0                                     297030            1280172.28
# 1                                     217586            1277557.12
# 2                                      88625              34823.52
# 3                                      84289             572940.33
# 4                                       7826              39249.13
# ...                                      ...                   ...
# 2125                                     NaN                   NaN
# 2126                                     NaN                   NaN
# 2127                                     NaN                   NaN
# 2128                                     NaN                   NaN
# 2129                                     NaN                   NaN
#
#      Densidad\n(2020)  Altitud (msnm)\n 3/  Latitud\nsur\n 3/  \
# 0           26.866262                  NaN                NaN
# 1           18.933502                  NaN                NaN
# 2          323.375322               162.42         -12.045278
# 3           17.387538                  NaN                NaN
# 4           12.051044              2338.00          -6.229444
# ...               ...                  ...                ...
# 2125              NaN                  NaN                NaN
# 2126              NaN                  NaN                NaN
# 2127              NaN                  NaN                NaN
# 2128              NaN                  NaN                NaN
# 2129              NaN                  NaN                NaN
#
#       Longitud oeste\n 3/  Número de Centros Poblados\n3/  \
# 0                     NaN                         94922.0
# 1                     NaN                         94811.0
# 2              -77.030833                          5229.0
# 3                     NaN                         22540.0
# 4              -77.872778                          3174.0
# ...                   ...                             ...
# 2125                  NaN                             NaN
# 2126                  NaN                             NaN
# 2127                  NaN                             NaN
# 2128                  NaN                             NaN
# 2129                  NaN                             NaN
#
#      Porcentaje de desnutrición crónica\n (Niños menores de 5 años) \n(2020)\n9/  \
# 0                                             12.067981
# 1                                             14.864528
# 2                                              5.085055
# 3                                              15.73736
# 4                                             17.467389
# ...                                                 ...
# 2125                                                NaN
# 2126                                                NaN
# 2127                                                NaN
# 2128                                                NaN
# 2129                                                NaN
#
#       Pobreza total: Número de habitantes en situación de pobreza\n\n16b/  \
# 0                                          1.035243e+07
# 1                                          7.673663e+06
# 2                                          2.956030e+06
# 3                                          3.171351e+06
# 4                                          1.558512e+05
# ...                                                 ...
# 2125                                                NaN
# 2126                                                NaN
# 2127                                                NaN
# 2128                                                NaN
# 2129                                                NaN
#
#       Pobreza extrema: Número de habitantes en situación de pobreza extrema \n17b/  \
# 0                                          1.754066e+06
# 1                                          1.442819e+06
# 2                                          3.434625e+05
# 3                                          5.842626e+05
# 4                                          3.452849e+04
# ...                                                 ...
# 2125                                                NaN
# 2126                                                NaN
# 2127                                                NaN
# 2128                                                NaN
# 2129                                                NaN
#
#       Porcentaje de la población en pobreza extrema \n17a/
# 0                                              5.100000
# 1                                              5.964864
# 2                                              3.050000
# 3                                              5.864900
# 4                                              7.300000
# ...                                                 ...
# 2125                                                NaN
# 2126                                                NaN
# 2127                                                NaN
# 2128                                                NaN
# 2129                                                NaN
#
# [2130 rows x 15 columns]

# %%
ceplan.columns=['nivel', 'ubigeo', 'lugar','pobTotal','pobDiscapacidad', 
 'superficie','densidad', 'altitud','latitud', 'longitud',
 'numeroCentrosPoblados', 'porcentajeDesnutCronica5menos','conteoPobres','conteoPobresExtremos',
 'porcentajePobrezaExtrema']
ceplan=ceplan.iloc[:2102,:]
ceplan
# Out:
#              nivel                         ubigeo      lugar    pobTotal  \
# 0         Nacional                       NACIONAL        NaN  34393444.0
# 1     Nacional_esp  NACIONAL SIN LA PROV. DE LIMA        NaN  24188630.0
# 2           Región                         150000       LIMA  11261067.0
# 3             Zona                     ZONA NORTE        NaN   9962022.0
# 4           Región                         010000   AMAZONAS    472993.0
# ...            ...                            ...        ...         ...
# 2097      Distrito                         230405   SITAJARA       381.0
# 2098      Distrito                         230406   SUSAPAYA       675.0
# 2099      Distrito                         230401     TARATA      3427.0
# 2100      Distrito                         230407  TARUCACHI       656.0
# 2101      Distrito                         230408     TICACO       942.0
#
#      pobDiscapacidad  superficie    densidad  altitud    latitud   longitud  \
# 0             297030  1280172.28   26.866262      NaN        NaN        NaN
# 1             217586  1277557.12   18.933502      NaN        NaN        NaN
# 2              88625    34823.52  323.375322   162.42 -12.045278 -77.030833
# 3              84289   572940.33   17.387538      NaN        NaN        NaN
# 4               7826    39249.13   12.051044  2338.00  -6.229444 -77.872778
# ...              ...         ...         ...      ...        ...        ...
# 2097               1      251.24    1.516478  3163.00 -17.375278 -70.133889
# 2098               4      373.21    1.808633  3462.00 -17.348056 -70.133611
# 2099              37      864.31    3.965013  3077.00 -17.475000 -70.031944
# 2100               1      113.27    5.791472  3054.00 -17.525833 -70.031667
# 2101               8      347.06    2.714228  3272.00 -17.447222 -70.046667
#
#       numeroCentrosPoblados porcentajeDesnutCronica5menos  conteoPobres  \
# 0                   94922.0                     12.067981  1.035243e+07
# 1                   94811.0                     14.864528  7.673663e+06
# 2                    5229.0                      5.085055  2.956030e+06
# 3                   22540.0                      15.73736  3.171351e+06
# 4                    3174.0                     17.467389  1.558512e+05
# ...                     ...                           ...           ...
# 2097                    6.0                          S.I.  1.005516e+02
# 2098                   71.0                     18.181818  1.856857e+02
# 2099                  137.0                      8.152174  1.253856e+03
# 2100                   13.0                            10  1.731282e+02
# 2101                   37.0                      30.30303  2.723153e+02
#
#       conteoPobresExtremos  porcentajePobrezaExtrema
# 0             1.754066e+06                  5.100000
# 1             1.442819e+06                  5.964864
# 2             3.434625e+05                  3.050000
# 3             5.842626e+05                  5.864900
# 4             3.452849e+04                  7.300000
# ...                    ...                       ...
# 2097          6.661640e+01                 17.484620
# 2098          1.655476e+02                 24.525570
# 2099          6.276352e+02                 18.314420
# 2100          3.770461e+01                  5.747654
# 2101          1.588962e+02                 16.867960
#
# [2102 rows x 15 columns]

# %%
ceplanDis=ceplan[ceplan.nivel=='Distrito']
ceplanDis.reset_index(drop=True,inplace=True)
ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("Á",'A',regex=False)
ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("É",'E',regex=False)
ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("Í",'I',regex=False)
ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("Ó",'O',regex=False)
ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("Ú",'U',regex=False)
ceplanDis
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/2617795740.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("Á",'A',regex=False)
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/2617795740.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("É",'E',regex=False)
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/2617795740.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("Í",'I',regex=False)
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/2617795740.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("Ó",'O',regex=False)
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/2617795740.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ceplanDis.loc[:,'lugar']=ceplanDis.lugar.str.replace("Ú",'U',regex=False)
#          nivel  ubigeo      lugar  pobTotal pobDiscapacidad superficie  \
# 0     Distrito  010202   ARAMANGO   12396.0             191     809.07
# 1     Distrito  010201      BAGUA   27423.0             513     150.99
# 2     Distrito  010203   COPALLIN    5694.0             129      99.05
# 3     Distrito  010204   EL PARCO    1719.0              19      18.48
# 4     Distrito  010205      IMAZA   40964.0             358    4430.84
# ...        ...     ...        ...       ...             ...        ...
# 1869  Distrito  230405   SITAJARA     381.0               1     251.24
# 1870  Distrito  230406   SUSAPAYA     675.0               4     373.21
# 1871  Distrito  230401     TARATA    3427.0              37     864.31
# 1872  Distrito  230407  TARUCACHI     656.0               1     113.27
# 1873  Distrito  230408     TICACO     942.0               8     347.06
#
#         densidad  altitud    latitud   longitud  numeroCentrosPoblados  \
# 0      15.321295    502.0  -5.416389 -78.437778                   87.0
# 1     181.621299    408.0  -5.638889 -78.531111                   24.0
# 2      57.486118    693.0  -5.675000 -78.423056                   31.0
# 3      93.019481    626.0  -5.625000 -78.475278                    9.0
# 4         9.2452    317.0  -5.163611 -78.288889                  159.0
# ...          ...      ...        ...        ...                    ...
# 1869    1.516478   3163.0 -17.375278 -70.133889                    6.0
# 1870    1.808633   3462.0 -17.348056 -70.133611                   71.0
# 1871    3.965013   3077.0 -17.475000 -70.031944                  137.0
# 1872    5.791472   3054.0 -17.525833 -70.031667                   13.0
# 1873    2.714228   3272.0 -17.447222 -70.046667                   37.0
#
#      porcentajeDesnutCronica5menos  conteoPobres  conteoPobresExtremos  \
# 0                         22.65343   4775.659036           2388.802170
# 1                        10.413031   4446.045742           1225.254978
# 2                        12.394366   1396.752891            640.212292
# 3                        15.463918    605.940418            209.014070
# 4                        36.580938  22099.951012          20026.824418
# ...                            ...           ...                   ...
# 1869                          S.I.    100.551577             66.616402
# 1870                     18.181818    185.685743            165.547597
# 1871                      8.152174   1253.856195            627.635173
# 1872                            10    173.128174             37.704610
# 1873                      30.30303    272.315282            158.896183
#
#       porcentajePobrezaExtrema
# 0                    19.270750
# 1                     4.467983
# 2                    11.243630
# 3                    12.159050
# 4                    48.888840
# ...                        ...
# 1869                 17.484620
# 1870                 24.525570
# 1871                 18.314420
# 1872                  5.747654
# 1873                 16.867960
#
# [1874 rows x 15 columns]

# %%
InCeplan=set(ceplanDis.lugar)-set(CongrePresiYanay600.DISTRITO)
InYanay=set(CongrePresiYanay600.DISTRITO)-set(ceplanDis.lugar)

# %%
changesCeplan={dis: process.extractOne(dis, InYanay)[0] for dis in sorted(InCeplan)}# if process.extractOne(dis, InCeplan)[1]>70}
changesCeplan#, len(changesb600)
# Out:
# {'CAPAZO': 'CAPASO',
#  'CARMEN DE LA LEGUA REYNOSO': 'CARMEN DE LA LEGUA-REYNOSO',
#  'CASPISAPA': 'CASPIZAPA',
#  'CRNEL.GREGORIO ALBARRACIN LANCHIPA': 'CORONEL GREGORIO ALBARRACIN LANCHIPA',
#  'ESTIQUE-PAMPA': 'ESTIQUE PAMPA',
#  'GAMARRA': 'MARISCAL GAMARRA',
#  'HUAYA': 'HUALLA',
#  'HUAYLLAY GRANDE': 'HUALLAY-GRANDE',
#  'HUAYLLO': 'IHUAYLLO',
#  'LA PECA a/': 'LA PECA',
#  'MILPUC': 'MILPUCC',
#  'RAYMONDI': 'RAIMONDI',
#  'RINCONADA LLICUAR': 'RINCONADA-LLICUAR',
#  'SAN JUAN DE ISCOS': 'SAN JUAN DE YSCOS',
#  'SANTA BARBARA DE CARHUACAYA': 'SANTA BARBARA DE CARHUACAYAN',
#  'SANTA CRUZ DE TOLEDO': 'SANTA CRUZ DE TOLED',
#  'SANTA RITA DE SIGUAS': 'SANTA RITA DE SIHUAS',
#  'TOMAY KICHWA': 'TOMAY-KICHWA'}

# %%
ceplanDis.lugar.replace(changesCeplan,inplace=True)
ceplanDis
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/1715716042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ceplanDis.lugar.replace(changesCeplan,inplace=True)
#          nivel  ubigeo      lugar  pobTotal pobDiscapacidad superficie  \
# 0     Distrito  010202   ARAMANGO   12396.0             191     809.07
# 1     Distrito  010201      BAGUA   27423.0             513     150.99
# 2     Distrito  010203   COPALLIN    5694.0             129      99.05
# 3     Distrito  010204   EL PARCO    1719.0              19      18.48
# 4     Distrito  010205      IMAZA   40964.0             358    4430.84
# ...        ...     ...        ...       ...             ...        ...
# 1869  Distrito  230405   SITAJARA     381.0               1     251.24
# 1870  Distrito  230406   SUSAPAYA     675.0               4     373.21
# 1871  Distrito  230401     TARATA    3427.0              37     864.31
# 1872  Distrito  230407  TARUCACHI     656.0               1     113.27
# 1873  Distrito  230408     TICACO     942.0               8     347.06
#
#         densidad  altitud    latitud   longitud  numeroCentrosPoblados  \
# 0      15.321295    502.0  -5.416389 -78.437778                   87.0
# 1     181.621299    408.0  -5.638889 -78.531111                   24.0
# 2      57.486118    693.0  -5.675000 -78.423056                   31.0
# 3      93.019481    626.0  -5.625000 -78.475278                    9.0
# 4         9.2452    317.0  -5.163611 -78.288889                  159.0
# ...          ...      ...        ...        ...                    ...
# 1869    1.516478   3163.0 -17.375278 -70.133889                    6.0
# 1870    1.808633   3462.0 -17.348056 -70.133611                   71.0
# 1871    3.965013   3077.0 -17.475000 -70.031944                  137.0
# 1872    5.791472   3054.0 -17.525833 -70.031667                   13.0
# 1873    2.714228   3272.0 -17.447222 -70.046667                   37.0
#
#      porcentajeDesnutCronica5menos  conteoPobres  conteoPobresExtremos  \
# 0                         22.65343   4775.659036           2388.802170
# 1                        10.413031   4446.045742           1225.254978
# 2                        12.394366   1396.752891            640.212292
# 3                        15.463918    605.940418            209.014070
# 4                        36.580938  22099.951012          20026.824418
# ...                            ...           ...                   ...
# 1869                          S.I.    100.551577             66.616402
# 1870                     18.181818    185.685743            165.547597
# 1871                      8.152174   1253.856195            627.635173
# 1872                            10    173.128174             37.704610
# 1873                      30.30303    272.315282            158.896183
#
#       porcentajePobrezaExtrema
# 0                    19.270750
# 1                     4.467983
# 2                    11.243630
# 3                    12.159050
# 4                    48.888840
# ...                        ...
# 1869                 17.484620
# 1870                 24.525570
# 1871                 18.314420
# 1872                  5.747654
# 1873                 16.867960
#
# [1874 rows x 15 columns]

# %%
ceplanReg=ceplan[ceplan.nivel=='Región'][['ubigeo','lugar']]
ceplanReg.reset_index(drop=True,inplace=True)
ceplanReg.loc[:,'lugar']=ceplanReg.lugar.str.replace("Á",'A',regex=False)
ceplanReg.loc[:,'lugar']=ceplanReg.lugar.str.replace("É",'E',regex=False)
ceplanReg.loc[:,'lugar']=ceplanReg.lugar.str.replace("Í",'I',regex=False)
ceplanReg.loc[:,'lugar']=ceplanReg.lugar.str.replace("Ó",'O',regex=False)
ceplanReg.loc[:,'lugar']=ceplanReg.lugar.str.replace("Ú",'U',regex=False)
ceplanReg.columns=['ubireg','DEPARTAMENTO']
ceplanReg
# Out:
#     ubireg   DEPARTAMENTO
# 0   150000           LIMA
# 1   010000       AMAZONAS
# 2   060000      CAJAMARCA
# 3   130000    LA LIBERTAD
# 4   140000     LAMBAYEQUE
# 5   160000         LORETO
# 6   200000          PIURA
# 7   220000     SAN MARTIN
# 8   240000         TUMBES
# 9   020000         ANCASH
# 10  070000         CALLAO
# 11  100000        HUANUCO
# 12  120000          JUNIN
# 13  190000          PASCO
# 14  250000        UCAYALI
# 15  030000       APURIMAC
# 16  040000       AREQUIPA
# 17  050000       AYACUCHO
# 18  080000          CUSCO
# 19  090000   HUANCAVELICA
# 20  110000            ICA
# 21  170000  MADRE DE DIOS
# 22  180000       MOQUEGUA
# 23  210000           PUNO
# 24  230000          TACNA

# %%
ceplanProv=ceplan[ceplan.nivel.str.contains('Prov')][['ubigeo','lugar']]
ceplanProv.reset_index(drop=True,inplace=True)
ceplanProv.loc[:,'lugar']=ceplanProv.lugar.str.replace("Á",'A',regex=False)
ceplanProv.loc[:,'lugar']=ceplanProv.lugar.str.replace("É",'E',regex=False)
ceplanProv.loc[:,'lugar']=ceplanProv.lugar.str.replace("Í",'I',regex=False)
ceplanProv.loc[:,'lugar']=ceplanProv.lugar.str.replace("Ó",'O',regex=False)
ceplanProv.loc[:,'lugar']=ceplanProv.lugar.str.replace("Ú",'U',regex=False)
ceplanProv.columns=['ubiprov','PROVINCIA']
ceplanProv
# Out:
#     ubiprov      PROVINCIA
# 0    010200          BAGUA
# 1    010300        BONGARA
# 2    010100    CHACHAPOYAS
# 3    010400   CONDORCANQUI
# 4    010500           LUYA
# ..      ...            ...
# 191  211300        YUNGUYO
# 192  230200      CANDARAVE
# 193  230300  JORGE BASADRE
# 194  230100          TACNA
# 195  230400         TARATA
#
# [196 rows x 2 columns]

# %%
ceplanDis['ubiprov']=[cod[:4]+'00' for cod in ceplanDis.ubigeo]
ceplanDis['ubireg']=[cod[:2]+'0000' for cod in ceplanDis.ubigeo]
ceplanDis
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/4013468122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ceplanDis['ubiprov']=[cod[:4]+'00' for cod in ceplanDis.ubigeo]
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/4013468122.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ceplanDis['ubireg']=[cod[:2]+'0000' for cod in ceplanDis.ubigeo]
#          nivel  ubigeo      lugar  pobTotal pobDiscapacidad superficie  \
# 0     Distrito  010202   ARAMANGO   12396.0             191     809.07
# 1     Distrito  010201      BAGUA   27423.0             513     150.99
# 2     Distrito  010203   COPALLIN    5694.0             129      99.05
# 3     Distrito  010204   EL PARCO    1719.0              19      18.48
# 4     Distrito  010205      IMAZA   40964.0             358    4430.84
# ...        ...     ...        ...       ...             ...        ...
# 1869  Distrito  230405   SITAJARA     381.0               1     251.24
# 1870  Distrito  230406   SUSAPAYA     675.0               4     373.21
# 1871  Distrito  230401     TARATA    3427.0              37     864.31
# 1872  Distrito  230407  TARUCACHI     656.0               1     113.27
# 1873  Distrito  230408     TICACO     942.0               8     347.06
#
#         densidad  altitud    latitud   longitud  numeroCentrosPoblados  \
# 0      15.321295    502.0  -5.416389 -78.437778                   87.0
# 1     181.621299    408.0  -5.638889 -78.531111                   24.0
# 2      57.486118    693.0  -5.675000 -78.423056                   31.0
# 3      93.019481    626.0  -5.625000 -78.475278                    9.0
# 4         9.2452    317.0  -5.163611 -78.288889                  159.0
# ...          ...      ...        ...        ...                    ...
# 1869    1.516478   3163.0 -17.375278 -70.133889                    6.0
# 1870    1.808633   3462.0 -17.348056 -70.133611                   71.0
# 1871    3.965013   3077.0 -17.475000 -70.031944                  137.0
# 1872    5.791472   3054.0 -17.525833 -70.031667                   13.0
# 1873    2.714228   3272.0 -17.447222 -70.046667                   37.0
#
#      porcentajeDesnutCronica5menos  conteoPobres  conteoPobresExtremos  \
# 0                         22.65343   4775.659036           2388.802170
# 1                        10.413031   4446.045742           1225.254978
# 2                        12.394366   1396.752891            640.212292
# 3                        15.463918    605.940418            209.014070
# 4                        36.580938  22099.951012          20026.824418
# ...                            ...           ...                   ...
# 1869                          S.I.    100.551577             66.616402
# 1870                     18.181818    185.685743            165.547597
# 1871                      8.152174   1253.856195            627.635173
# 1872                            10    173.128174             37.704610
# 1873                      30.30303    272.315282            158.896183
#
#       porcentajePobrezaExtrema ubiprov  ubireg
# 0                    19.270750  010200  010000
# 1                     4.467983  010200  010000
# 2                    11.243630  010200  010000
# 3                    12.159050  010200  010000
# 4                    48.888840  010200  010000
# ...                        ...     ...     ...
# 1869                 17.484620  230400  230000
# 1870                 24.525570  230400  230000
# 1871                 18.314420  230400  230000
# 1872                  5.747654  230400  230000
# 1873                 16.867960  230400  230000
#
# [1874 rows x 17 columns]

# %%
ceplanDis=ceplanDis.merge(ceplanReg,on="ubireg")
ceplanDis=ceplanDis.merge(ceplanProv,on="ubiprov")
ceplanDis
# Out:
#          nivel  ubigeo      lugar  pobTotal pobDiscapacidad superficie  \
# 0     Distrito  010202   ARAMANGO   12396.0             191     809.07
# 1     Distrito  010201      BAGUA   27423.0             513     150.99
# 2     Distrito  010203   COPALLIN    5694.0             129      99.05
# 3     Distrito  010204   EL PARCO    1719.0              19      18.48
# 4     Distrito  010205      IMAZA   40964.0             358    4430.84
# ...        ...     ...        ...       ...             ...        ...
# 1869  Distrito  230405   SITAJARA     381.0               1     251.24
# 1870  Distrito  230406   SUSAPAYA     675.0               4     373.21
# 1871  Distrito  230401     TARATA    3427.0              37     864.31
# 1872  Distrito  230407  TARUCACHI     656.0               1     113.27
# 1873  Distrito  230408     TICACO     942.0               8     347.06
#
#         densidad  altitud    latitud   longitud  numeroCentrosPoblados  \
# 0      15.321295    502.0  -5.416389 -78.437778                   87.0
# 1     181.621299    408.0  -5.638889 -78.531111                   24.0
# 2      57.486118    693.0  -5.675000 -78.423056                   31.0
# 3      93.019481    626.0  -5.625000 -78.475278                    9.0
# 4         9.2452    317.0  -5.163611 -78.288889                  159.0
# ...          ...      ...        ...        ...                    ...
# 1869    1.516478   3163.0 -17.375278 -70.133889                    6.0
# 1870    1.808633   3462.0 -17.348056 -70.133611                   71.0
# 1871    3.965013   3077.0 -17.475000 -70.031944                  137.0
# 1872    5.791472   3054.0 -17.525833 -70.031667                   13.0
# 1873    2.714228   3272.0 -17.447222 -70.046667                   37.0
#
#      porcentajeDesnutCronica5menos  conteoPobres  conteoPobresExtremos  \
# 0                         22.65343   4775.659036           2388.802170
# 1                        10.413031   4446.045742           1225.254978
# 2                        12.394366   1396.752891            640.212292
# 3                        15.463918    605.940418            209.014070
# 4                        36.580938  22099.951012          20026.824418
# ...                            ...           ...                   ...
# 1869                          S.I.    100.551577             66.616402
# 1870                     18.181818    185.685743            165.547597
# 1871                      8.152174   1253.856195            627.635173
# 1872                            10    173.128174             37.704610
# 1873                      30.30303    272.315282            158.896183
#
#       porcentajePobrezaExtrema ubiprov  ubireg DEPARTAMENTO PROVINCIA
# 0                    19.270750  010200  010000     AMAZONAS     BAGUA
# 1                     4.467983  010200  010000     AMAZONAS     BAGUA
# 2                    11.243630  010200  010000     AMAZONAS     BAGUA
# 3                    12.159050  010200  010000     AMAZONAS     BAGUA
# 4                    48.888840  010200  010000     AMAZONAS     BAGUA
# ...                        ...     ...     ...          ...       ...
# 1869                 17.484620  230400  230000        TACNA    TARATA
# 1870                 24.525570  230400  230000        TACNA    TARATA
# 1871                 18.314420  230400  230000        TACNA    TARATA
# 1872                  5.747654  230400  230000        TACNA    TARATA
# 1873                 16.867960  230400  230000        TACNA    TARATA
#
# [1874 rows x 19 columns]

# %%
ceplanDis.drop(columns=['ubiprov','ubireg'],inplace=True)
ceplanDis.head()
# Out:
#       nivel  ubigeo     lugar  pobTotal pobDiscapacidad superficie  \
# 0  Distrito  010202  ARAMANGO   12396.0             191     809.07
# 1  Distrito  010201     BAGUA   27423.0             513     150.99
# 2  Distrito  010203  COPALLIN    5694.0             129      99.05
# 3  Distrito  010204  EL PARCO    1719.0              19      18.48
# 4  Distrito  010205     IMAZA   40964.0             358    4430.84
#
#      densidad  altitud   latitud   longitud  numeroCentrosPoblados  \
# 0   15.321295    502.0 -5.416389 -78.437778                   87.0
# 1  181.621299    408.0 -5.638889 -78.531111                   24.0
# 2   57.486118    693.0 -5.675000 -78.423056                   31.0
# 3   93.019481    626.0 -5.625000 -78.475278                    9.0
# 4      9.2452    317.0 -5.163611 -78.288889                  159.0
#
#   porcentajeDesnutCronica5menos  conteoPobres  conteoPobresExtremos  \
# 0                      22.65343   4775.659036           2388.802170
# 1                     10.413031   4446.045742           1225.254978
# 2                     12.394366   1396.752891            640.212292
# 3                     15.463918    605.940418            209.014070
# 4                     36.580938  22099.951012          20026.824418
#
#    porcentajePobrezaExtrema DEPARTAMENTO PROVINCIA
# 0                 19.270750     AMAZONAS     BAGUA
# 1                  4.467983     AMAZONAS     BAGUA
# 2                 11.243630     AMAZONAS     BAGUA
# 3                 12.159050     AMAZONAS     BAGUA
# 4                 48.888840     AMAZONAS     BAGUA

# %%
InCeplan=set(ceplanDis.PROVINCIA)-set(CongrePresiYanay600.PROVINCIA)
InYana=set(CongrePresiYanay600.PROVINCIA)-set(ceplanDis.PROVINCIA)

# %%
InCeplan
# Out:
# {'ANTONIO RAYMONDI', 'CARLOS F. FITZCARRALD', 'FAJARDO', 'PROVINCIA DE LIMA'}

# %%
changesCeplan2={prov: process.extractOne(prov, InYana)[0] for prov in sorted(InCeplan)}# if process.extractOne(dis, InCeplan)[1]>70}
changesCeplan2#, len(changesb600)
# Out:
# {'ANTONIO RAYMONDI': 'ANTONIO RAIMONDI',
#  'CARLOS F. FITZCARRALD': 'CARLOS FERMIN FITZCARRALD',
#  'FAJARDO': 'VICTOR FAJARDO',
#  'PROVINCIA DE LIMA': 'LIMA'}

# %%
ceplanDis.PROVINCIA.replace(changesCeplan2,inplace=True)

# %%
newkeys={'lugar':'DISTRITO'}
ceplanDis.rename(columns=newkeys,inplace=True)

# %%
set(CongrePresiYanay600.DISTRITO)-set(ceplanDis.DISTRITO)
# Out:
# {'SAN PEDRO DE LARAOS'}

# %%
ceplanDis[(ceplanDis.DISTRITO=="LARAOS") & (ceplanDis.PROVINCIA=='HUAROCHIRI')]
# Out:
#          nivel  ubigeo DISTRITO  pobTotal pobDiscapacidad superficie  \
# 1019  Distrito  150712   LARAOS     372.0            S.I.     104.51
#
#       densidad  altitud    latitud   longitud  numeroCentrosPoblados  \
# 1019  3.559468   3683.0 -11.664444 -76.539444                    8.0
#
#      porcentajeDesnutCronica5menos  conteoPobres  conteoPobresExtremos  \
# 1019                     45.454545      70.48098             21.336882
#
#       porcentajePobrezaExtrema DEPARTAMENTO   PROVINCIA
# 1019                  5.735721         LIMA  HUAROCHIRI

# %%
ceplanDis.loc[1019,'DISTRITO']='SAN PEDRO DE LARAOS'

# %%
theKeys
# Out:
# ['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO']

# %%
test=CongrePresiYanay600.merge(ceplanDis,on=theKeys,how='outer',indicator=True)
test[test['_merge']!='both']
# Out:
# Empty DataFrame
# Columns: [UBIGEO_yana, UBIGEO, DEPARTAMENTO, PROVINCIA, DISTRITO, programado_yana, ejecutado_yana, yanaProp, PeruLibre_congre, congreEmitidos, proporcion_congre, PeruLibre_presi, presiEmitidos, proporcion_presi, programado_b600, ejecutado_b600, nivel, ubigeo, pobTotal, pobDiscapacidad, superficie, densidad, altitud, latitud, longitud, numeroCentrosPoblados, porcentajeDesnutCronica5menos, conteoPobres, conteoPobresExtremos, porcentajePobrezaExtrema, _merge]
# Index: []
#
# [0 rows x 31 columns]

# %%
CongrePresiYanay600[CongrePresiYanay600.DISTRITO=="LARAOS"]
# Out:
#       UBIGEO_yana  UBIGEO DEPARTAMENTO PROVINCIA DISTRITO  programado_yana  \
# 1435       151018  140716         LIMA    YAUYOS   LARAOS              415
#
#       ejecutado_yana  yanaProp  PeruLibre_congre  congreEmitidos  \
# 1435             369  0.889157              50.0           257.0
#
#       proporcion_congre  PeruLibre_presi  presiEmitidos  proporcion_presi  \
# 1435           0.194553             56.0          257.0          0.217899
#
#       programado_b600  ejecutado_b600
# 1435              251             229

# %%
CongrePresiYanay600CEPLAN=CongrePresiYanay600.merge(ceplanDis,on=theKeys)
CongrePresiYanay600CEPLAN
# Out:
#       UBIGEO_yana  UBIGEO DEPARTAMENTO    PROVINCIA                DISTRITO  \
# 0           10101   10101     AMAZONAS  CHACHAPOYAS             CHACHAPOYAS
# 1           10102   10102     AMAZONAS  CHACHAPOYAS                ASUNCION
# 2           10103   10103     AMAZONAS  CHACHAPOYAS                  BALSAS
# 3           10104   10104     AMAZONAS  CHACHAPOYAS                   CHETO
# 4           10105   10105     AMAZONAS  CHACHAPOYAS               CHILIQUIN
# ...           ...     ...          ...          ...                     ...
# 1869       250302  250202      UCAYALI   PADRE ABAD                 IRAZOLA
# 1870       250303  250203      UCAYALI   PADRE ABAD                CURIMANA
# 1871       250304  250204      UCAYALI   PADRE ABAD                 NESHUYA
# 1872       250305  250205      UCAYALI   PADRE ABAD  ALEXANDER VON HUMBOLDT
# 1873       250401  250401      UCAYALI        PURUS                   PURUS
#
#       programado_yana  ejecutado_yana  yanaProp  PeruLibre_congre  \
# 0               12656           12126  0.958123             718.0
# 1                 181             176  0.972376               5.0
# 2                 848             790  0.931604              97.0
# 3                 505             490  0.970297              19.0
# 4                 513             486  0.947368              18.0
# ...               ...             ...       ...               ...
# 1869             7881            6822  0.865626            1149.0
# 1870             6258            5567  0.889581             896.0
# 1871             4057            3731  0.919645             526.0
# 1872             3396            3017  0.888398             457.0
# 1873             2365            2065  0.873150              51.0
#
#       congreEmitidos  ...  superficie    densidad  altitud   latitud  \
# 0            13427.0  ...      153.78  201.437118   2338.0 -6.229444
# 1              114.0  ...       25.71   13.963438   2823.0 -6.032500
# 2              504.0  ...      357.09    4.046599    859.0 -6.835833
# 3              411.0  ...       56.97   13.568545   2143.0 -6.255556
# 4              324.0  ...      143.43    6.832601   2677.0 -6.078333
# ...              ...  ...         ...         ...      ...       ...
# 1869          6535.0  ...      998.93   16.256394    228.0 -8.828611
# 1870          4142.0  ...     2134.04      5.3387    181.0 -8.433333
# 1871          3854.0  ...      579.51   14.627875    193.0 -8.640000
# 1872          2670.0  ...       190.8   28.155136    237.0 -8.827500
# 1873          1282.0  ...    17847.76    0.279979    228.0 -9.772222
#
#        longitud  numeroCentrosPoblados porcentajeDesnutCronica5menos  \
# 0    -77.872778                   27.0                     11.698538
# 1    -77.710833                    9.0                     14.285714
# 2    -78.019722                   27.0                     23.308271
# 3    -77.700833                   13.0                     15.789474
# 4    -77.737500                   37.0                     18.032787
# ...         ...                    ...                           ...
# 1869 -75.213333                   66.0                     19.905213
# 1870 -75.147778                   39.0                     18.617021
# 1871 -74.964444                   27.0                     18.810512
# 1872 -75.050833                   14.0                     10.687023
# 1873 -70.709722                   49.0                     39.473684
#
#      conteoPobres  conteoPobresExtremos porcentajePobrezaExtrema
# 0     2798.655786            446.030079                 1.439875
# 1      131.106617             56.293892                15.680750
# 2      660.841301            222.921884                15.427120
# 3      302.782415            183.034109                23.678410
# 4      519.847488            356.674626                36.395370
# ...           ...                   ...                      ...
# 1869  2094.759548            326.178178                 2.008610
# 1870  1027.027112             99.744804                 0.875492
# 1871  1012.735068             44.751015                 0.527911
# 1872   692.964363             33.764041                 0.628519
# 1873  1595.459050             78.876146                 1.578470
#
# [1874 rows x 30 columns]

# %%
CongrePresiYanay600CEPLAN.loc[:,'pobDiscapacidad']=pd.to_numeric(CongrePresiYanay600CEPLAN.pobDiscapacidad, errors='coerce')
CongrePresiYanay600CEPLAN.loc[:,'superficie']=pd.to_numeric(CongrePresiYanay600CEPLAN.superficie, errors='coerce')
CongrePresiYanay600CEPLAN.loc[:,'densidad']=pd.to_numeric(CongrePresiYanay600CEPLAN.densidad, errors='coerce')
CongrePresiYanay600CEPLAN.loc[:,'porcentajeDesnutCronica5menos']=pd.to_numeric(CongrePresiYanay600CEPLAN.porcentajeDesnutCronica5menos, errors='coerce')
CongrePresiYanay600CEPLAN.conteoPobres=CongrePresiYanay600CEPLAN.conteoPobres.astype(int)
CongrePresiYanay600CEPLAN.conteoPobresExtremos=CongrePresiYanay600CEPLAN.conteoPobresExtremos.astype(int)
CongrePresiYanay600CEPLAN['b600prop']=CongrePresiYanay600CEPLAN.ejecutado_b600/CongrePresiYanay600CEPLAN.programado_b600

# %%
CongrePresiYanay600CEPLAN.to_csv('CongrePresiYanay600CEPLAN.csv',index=False)

# %%
import geopandas as gpd

linkGit="https://github.com/chorrillos/preprocesamiento/raw/main/distritos/DistritosMap.zip"
datadismap=gpd.read_file(linkGit)

# %%
datadismap.rename(columns={'DEPARTAMEN':'DEPARTAMENTO'},inplace=True)
datadismap
# Out:
#      DEPARTAMENTO PROVINCIA                              DISTRITO INSTITUCIO  \
# 0           TACNA     TACNA  CORONEL GREGORIO ALBARRACIN LANCHIPA        IGN
# 1           TACNA     TACNA                              POCOLLAY        IGN
# 2           TACNA     TACNA                                CALANA        IGN
# 3           TACNA     TACNA                                 TACNA        IGN
# 4           TACNA     TACNA                                  SAMA        IGN
# ...           ...       ...                                   ...        ...
# 1869         LIMA      LIMA                           CIENEGUILLA        IGN
# 1870         LIMA      LIMA                                 ANCON        IGN
# 1871         LIMA      LIMA                            CARABAYLLO        IGN
# 1872       CALLAO    CALLAO                               MI PERU        IGN
# 1873         LIMA      LIMA                     SANTIAGO DE SURCO        IGN
#
#                                                geometry
# 0     POLYGON ((-70.17413 -18.12896, -70.17461 -18.1...
# 1     POLYGON ((-69.93475 -17.92557, -69.90467 -17.9...
# 2     POLYGON ((-70.11604 -17.91106, -70.11457 -17.9...
# 3     POLYGON ((-70.31490 -17.94498, -70.30682 -17.9...
# 4     POLYGON ((-70.42497 -17.88934, -70.48022 -17.9...
# ...                                                 ...
# 1869  POLYGON ((-76.72917 -11.99948, -76.72596 -11.9...
# 1870  POLYGON ((-77.06501 -11.57523, -77.06499 -11.5...
# 1871  POLYGON ((-76.89892 -11.72963, -76.89768 -11.7...
# 1872  POLYGON ((-77.11491 -11.84189, -77.11450 -11.8...
# 1873  POLYGON ((-76.95742 -12.07604, -76.95741 -12.0...
#
# [1874 rows x 5 columns]

# %%
datadismap.loc[:,'DISTRITO']=datadismap.DISTRITO.str.replace("Á",'A',regex=False)
datadismap.loc[:,'DISTRITO']=datadismap.DISTRITO.str.replace("É",'E',regex=False)
datadismap.loc[:,'DISTRITO']=datadismap.DISTRITO.str.replace("Í",'I',regex=False)
datadismap.loc[:,'DISTRITO']=datadismap.DISTRITO.str.replace("Ó",'O',regex=False)
datadismap.loc[:,'DISTRITO']=datadismap.DISTRITO.str.replace("Ú",'U',regex=False)

# %%
datadismap.loc[:,'PROVINCIA']=datadismap.PROVINCIA.str.replace("Á",'A',regex=False)
datadismap.loc[:,'PROVINCIA']=datadismap.PROVINCIA.str.replace("É",'E',regex=False)
datadismap.loc[:,'PROVINCIA']=datadismap.PROVINCIA.str.replace("Í",'I',regex=False)
datadismap.loc[:,'PROVINCIA']=datadismap.PROVINCIA.str.replace("Ó",'O',regex=False)
datadismap.loc[:,'PROVINCIA']=datadismap.PROVINCIA.str.replace("Ú",'U',regex=False)

# %%
datadismap.loc[:,'DISTRITO']=datadismap.DISTRITO.str.replace("\xa0",'',regex=False)

# %%
inMapP=set(datadismap.PROVINCIA) -set(CongrePresiYanay600CEPLAN.PROVINCIA)
inTableP= set(CongrePresiYanay600CEPLAN.PROVINCIA)-set(datadismap.PROVINCIA)
inMapP
# Out:
# {'ANTONIO RAYMONDI', 'NAZCA', 'VILCAS-HUAMAN'}

# %%
inMap=set(datadismap.DISTRITO) -set(CongrePresiYanay600CEPLAN.DISTRITO)
inTable= set(CongrePresiYanay600CEPLAN.DISTRITO)-set(datadismap.DISTRITO)
inMap
# Out:
# {'ANCO HUALLO',
#  'AYAUCA',
#  'CAPAZO',
#  'CARAIBAMBA',
#  'CARMEN DE LA LEGUA REYNOSO',
#  'CASPISAPA',
#  'ELIAS SOPLíN VARGAS',
#  'GAMARRA',
#  'HUALLAY GRANDE',
#  'HUANCA HUANCA',
#  'HUAYA',
#  'MAGDALENA VIEJA',
#  'MARIANO NICOLAS VALCáRCEL',
#  'MASMA-CHICCHE',
#  'MILPUC',
#  'NAZCA',
#  'PAPA-PLAYA',
#  'RAYMONDI',
#  'SAN JOSE  DE TICLLAS',
#  'SAN JOSE DE  LOS MOLINOS',
#  'SANTA BARBARA DE CARHUACAYáN',
#  'SANTA RITA DE SIGUAS',
#  'TOMAY KICHWA',
#  'TRES-UNIDOS',
#  'TUNAN-MARCA'}

# %%
changesMapP={pro: process.extractOne(pro, inTableP)[0] for pro in sorted(inMapP)}# if process.extractOne(dis, inTableP)[1]>70}
changesMapP#, len(changesb600)
# Out:
# {'ANTONIO RAYMONDI': 'ANTONIO RAIMONDI',
#  'NAZCA': 'NASCA',
#  'VILCAS-HUAMAN': 'VILCAS HUAMAN'}

# %%
datadismap.PROVINCIA.replace(changesMapP,inplace=True)

# %%
changesMap={dis: process.extractOne(dis, inTable)[0] for dis in sorted(inMap) if process.extractOne(dis, inTable)[1]>70}
changesMap#, len(changesb600)
# Out:
# {'ANCO HUALLO': 'ANCO-HUALLO',
#  'AYAUCA': 'ALLAUCA',
#  'CAPAZO': 'CAPASO',
#  'CARAIBAMBA': 'CARAYBAMBA',
#  'CARMEN DE LA LEGUA REYNOSO': 'CARMEN DE LA LEGUA-REYNOSO',
#  'CASPISAPA': 'CASPIZAPA',
#  'ELIAS SOPLíN VARGAS': 'ELIAS SOPLIN VARGAS',
#  'GAMARRA': 'MARISCAL GAMARRA',
#  'HUALLAY GRANDE': 'HUALLAY-GRANDE',
#  'HUANCA HUANCA': 'HUANCA-HUANCA',
#  'HUAYA': 'HUALLA',
#  'MARIANO NICOLAS VALCáRCEL': 'MARIANO NICOLAS VALCARCEL',
#  'MASMA-CHICCHE': 'MASMA CHICCHE',
#  'MILPUC': 'MILPUCC',
#  'NAZCA': 'NASCA',
#  'PAPA-PLAYA': 'PAPAPLAYA',
#  'RAYMONDI': 'RAIMONDI',
#  'SAN JOSE  DE TICLLAS': 'SAN JOSE DE TICLLAS',
#  'SAN JOSE DE  LOS MOLINOS': 'SAN JOSE DE LOS MOLINOS',
#  'SANTA BARBARA DE CARHUACAYáN': 'SANTA BARBARA DE CARHUACAYAN',
#  'SANTA RITA DE SIGUAS': 'SANTA RITA DE SIHUAS',
#  'TOMAY KICHWA': 'TOMAY-KICHWA',
#  'TRES-UNIDOS': 'TRES UNIDOS',
#  'TUNAN-MARCA': 'TUNAN MARCA'}

# %%
datadismap.DISTRITO.replace(changesMap,inplace=True)

# %%
datadismap[datadismap.DISTRITO.str.contains('VIEJA')]
# Out:
#      DEPARTAMENTO PROVINCIA         DISTRITO INSTITUCIO  \
# 1851         LIMA      LIMA  MAGDALENA VIEJA        IGN
#
#                                                geometry
# 1851  POLYGON ((-77.06281 -12.08602, -77.06321 -12.0...

# %%
datadismap.loc[1851,'DISTRITO']='PUEBLO LIBRE'

# %%
datadismap[datadismap.DISTRITO.str.contains('LARAOS')]
# Out:
#     DEPARTAMENTO   PROVINCIA DISTRITO INSTITUCIO  \
# 726         LIMA      YAUYOS   LARAOS        IGN
# 878         LIMA  HUAROCHIRI   LARAOS        IGN
#
#                                               geometry
# 726  POLYGON ((-75.60926 -12.29437, -75.60764 -12.2...
# 878  POLYGON ((-76.48761 -11.45742, -76.48737 -11.4...

# %%
datadismap.loc[878,'DISTRITO']='SAN PEDRO DE LARAOS'

# %%
CongrePresiYanay600CEPLAN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1874 entries, 0 to 1873
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   UBIGEO_yana                    1874 non-null   int64
#  1   UBIGEO                         1874 non-null   int64
#  2   DEPARTAMENTO                   1874 non-null   object
#  3   PROVINCIA                      1874 non-null   object
#  4   DISTRITO                       1874 non-null   object
#  5   programado_yana                1874 non-null   int64
#  6   ejecutado_yana                 1874 non-null   int64
#  7   yanaProp                       1874 non-null   float64
#  8   PeruLibre_congre               1798 non-null   float64
#  9   congreEmitidos                 1874 non-null   float64
#  10  proporcion_congre              1798 non-null   float64
#  11  PeruLibre_presi                1874 non-null   float64
#  12  presiEmitidos                  1874 non-null   float64
#  13  proporcion_presi               1874 non-null   float64
#  14  programado_b600                1874 non-null   int64
#  15  ejecutado_b600                 1874 non-null   int64
#  16  nivel                          1874 non-null   object
#  17  ubigeo                         1874 non-null   object
#  18  pobTotal                       1874 non-null   float64
#  19  pobDiscapacidad                1805 non-null   float64
#  20  superficie                     1870 non-null   float64
#  21  densidad                       1870 non-null   float64
#  22  altitud                        1874 non-null   float64
#  23  latitud                        1874 non-null   float64
#  24  longitud                       1874 non-null   float64
#  25  numeroCentrosPoblados          1874 non-null   float64
#  26  porcentajeDesnutCronica5menos  1784 non-null   float64
#  27  conteoPobres                   1874 non-null   int64
#  28  conteoPobresExtremos           1874 non-null   int64
#  29  porcentajePobrezaExtrema       1874 non-null   float64
#  30  b600prop                       975 non-null    float64
# dtypes: float64(18), int64(8), object(5)
# memory usage: 468.5+ KB

# %%
midisceplanmap=datadismap.merge(CongrePresiYanay600CEPLAN,on=theKeys)
midisceplanmap
# Out:
#      DEPARTAMENTO PROVINCIA                              DISTRITO INSTITUCIO  \
# 0           TACNA     TACNA  CORONEL GREGORIO ALBARRACIN LANCHIPA        IGN
# 1           TACNA     TACNA                              POCOLLAY        IGN
# 2           TACNA     TACNA                                CALANA        IGN
# 3           TACNA     TACNA                                 TACNA        IGN
# 4           TACNA     TACNA                                  SAMA        IGN
# ...           ...       ...                                   ...        ...
# 1869         LIMA      LIMA                           CIENEGUILLA        IGN
# 1870         LIMA      LIMA                                 ANCON        IGN
# 1871         LIMA      LIMA                            CARABAYLLO        IGN
# 1872       CALLAO    CALLAO                               MI PERU        IGN
# 1873         LIMA      LIMA                     SANTIAGO DE SURCO        IGN
#
#                                                geometry  UBIGEO_yana  UBIGEO  \
# 0     POLYGON ((-70.17413 -18.12896, -70.17461 -18.1...       230110  220113
# 1     POLYGON ((-69.93475 -17.92557, -69.90467 -17.9...       230108  220109
# 2     POLYGON ((-70.11604 -17.91106, -70.11457 -17.9...       230103  220102
# 3     POLYGON ((-70.31490 -17.94498, -70.30682 -17.9...       230101  220101
# 4     POLYGON ((-70.42497 -17.88934, -70.48022 -17.9...       230109  220110
# ...                                                 ...          ...     ...
# 1869  POLYGON ((-76.72917 -11.99948, -76.72596 -11.9...       150109  140139
# 1870  POLYGON ((-77.06501 -11.57523, -77.06499 -11.5...       150102  140102
# 1871  POLYGON ((-76.89892 -11.72963, -76.89768 -11.7...       150106  140105
# 1872  POLYGON ((-77.11491 -11.84189, -77.11450 -11.8...        70107  240107
# 1873  POLYGON ((-76.95742 -12.07604, -76.95741 -12.0...       150140  140130
#
#       programado_yana  ejecutado_yana  yanaProp  ...      densidad  altitud  \
# 0               50230           46451  0.924766  ...    555.837861    562.0
# 1                7204            6746  0.936424  ...     67.216262    690.0
# 2                1879            1753  0.932943  ...     40.976195    881.0
# 3               40771           37323  0.915430  ...     69.744592    583.0
# 4                1766            1625  0.920159  ...      2.461514    397.0
# ...               ...             ...       ...  ...           ...      ...
# 1869            13032           12244  0.939533  ...    141.130945    287.0
# 1870            24109           22582  0.936663  ...    189.269574     14.0
# 1871           121488          114568  0.943040  ...   1027.671359    238.0
# 1872            11234           10810  0.962257  ...  16019.841270    118.0
# 1873            61759           52845  0.855665  ...  11733.045417    107.0
#
#         latitud   longitud  numeroCentrosPoblados  \
# 0    -18.043056 -70.251667                   32.0
# 1    -17.996667 -70.225833                   13.0
# 2    -17.943333 -70.188333                   37.0
# 3    -18.001944 -70.251944                   18.0
# 4    -17.862500 -70.560000                   33.0
# ...         ...        ...                    ...
# 1869 -12.120278 -76.814167                    8.0
# 1870 -11.773889 -77.176389                    1.0
# 1871 -11.890278 -77.026944                   31.0
# 1872 -11.855000 -77.125000                    1.0
# 1873 -12.145000 -77.005000                    1.0
#
#       porcentajeDesnutCronica5menos  conteoPobres  conteoPobresExtremos  \
# 0                          3.302912         19552                  1715
# 1                          2.813299          2393                   168
# 2                          3.333333           324                    19
# 3                          2.764423         10072                   296
# 4                          3.731343           292                    31
# ...                             ...           ...                   ...
# 1869                      11.968607          5945                   445
# 1870                       8.045113         10398                   746
# 1871                       9.366773         59772                  3619
# 1872                       7.207688          9665                   497
# 1873                       6.860552          5184                   187
#
#      porcentajePobrezaExtrema  b600prop
# 0                    1.644405  0.926729
# 1                    0.944194  0.929134
# 2                    0.432479  0.950739
# 3                    0.226073  0.912929
# 4                    1.143432  0.944355
# ...                       ...       ...
# 1869                 1.313477  0.949747
# 1870                 1.381812  0.940035
# 1871                 1.161094  0.950333
# 1872                 1.231299  0.966450
# 1873                 0.044496  0.875107
#
# [1874 rows x 33 columns]

# %%
midisceplanmap.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 1874 entries, 0 to 1873
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DEPARTAMENTO                   1874 non-null   object
#  1   PROVINCIA                      1874 non-null   object
#  2   DISTRITO                       1874 non-null   object
#  3   INSTITUCIO                     1874 non-null   object
#  4   geometry                       1874 non-null   geometry
#  5   UBIGEO_yana                    1874 non-null   int64
#  6   UBIGEO                         1874 non-null   int64
#  7   programado_yana                1874 non-null   int64
#  8   ejecutado_yana                 1874 non-null   int64
#  9   yanaProp                       1874 non-null   float64
#  10  PeruLibre_congre               1798 non-null   float64
#  11  congreEmitidos                 1874 non-null   float64
#  12  proporcion_congre              1798 non-null   float64
#  13  PeruLibre_presi                1874 non-null   float64
#  14  presiEmitidos                  1874 non-null   float64
#  15  proporcion_presi               1874 non-null   float64
#  16  programado_b600                1874 non-null   int64
#  17  ejecutado_b600                 1874 non-null   int64
#  18  nivel                          1874 non-null   object
#  19  ubigeo                         1874 non-null   object
#  20  pobTotal                       1874 non-null   float64
#  21  pobDiscapacidad                1805 non-null   float64
#  22  superficie                     1870 non-null   float64
#  23  densidad                       1870 non-null   float64
#  24  altitud                        1874 non-null   float64
#  25  latitud                        1874 non-null   float64
#  26  longitud                       1874 non-null   float64
#  27  numeroCentrosPoblados          1874 non-null   float64
#  28  porcentajeDesnutCronica5menos  1784 non-null   float64
#  29  conteoPobres                   1874 non-null   int64
#  30  conteoPobresExtremos           1874 non-null   int64
#  31  porcentajePobrezaExtrema       1874 non-null   float64
#  32  b600prop                       975 non-null    float64
# dtypes: float64(18), geometry(1), int64(8), object(6)
# memory usage: 497.8+ KB

# %%
midisceplanmap.to_file(filename='midisceplanmap.shp.zip', driver='ESRI Shapefile')
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/1482886471.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   midisceplanmap.to_file(filename='midisceplanmap.shp.zip', driver='ESRI Shapefile')

# %%
midis.plot()
# Out:
# <AxesSubplot:>

# %%
midisceplanmap.to_file("midisceplanmap.geojson", driver="GeoJSON")

# %%
midisceplanmap_repro=midisceplanmap.copy(deep=True)

# %%
midisceplanmap.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
midisceplanmap_repro=midisceplanmap_repro.to_crs("EPSG:5389")

# %%
midisceplanmap_repro.crs
# Out:
# <Derived Projected CRS: EPSG:5389>
# Name: Peru96 / UTM zone 19S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Peru - east of 72°W, onshore and offshore.
# - bounds: (-72.0, -20.44, -68.67, -2.14)
# Coordinate Operation:
# - name: UTM zone 19S
# - method: Transverse Mercator
# Datum: Peru96
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
midisceplanmap_repro['propDisca']=midisceplanmap_repro.pobDiscapacidad/midisceplanmap_repro.pobTotal
midisceplanmap_repro.to_file("midisceplanmap_repro.geojson", driver="GeoJSON")

# %%
midisceplanmap_repro_shapes=midisceplanmap_repro.copy(deep=True)

# %%
midisceplanmap_repro_shapes.columns
# Out:
# Index(['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'INSTITUCIO', 'geometry',
#        'UBIGEO_yana', 'UBIGEO', 'programado_yana', 'ejecutado_yana',
#        'yanaProp', 'PeruLibre_congre', 'congreEmitidos', 'proporcion_congre',
#        'PeruLibre_presi', 'presiEmitidos', 'proporcion_presi',
#        'programado_b600', 'ejecutado_b600', 'nivel', 'ubigeo', 'pobTotal',
#        'pobDiscapacidad', 'superficie', 'densidad', 'altitud', 'latitud',
#        'longitud', 'numeroCentrosPoblados', 'porcentajeDesnutCronica5menos',
#        'conteoPobres', 'conteoPobresExtremos', 'porcentajePobrezaExtrema',
#        'b600prop', 'propDisca'],
#       dtype='object')

# %%
namesShapes=['REGION', 'PROVINCIA', 'DISTRITO', 'INSTITUCIO', 'geometry',
       'UBI_yana', 'UBIGEO', 'prog_yana', 'ejec_yana',
       'yanaProp', 'PL_congre', 'EmitCongre', 'PropCongre',
       'PL_presi', 'EmitPresi', 'PropPresi',
       'prog_b600', 'ejec_b600', 'nivel', 'ubigeo', 'pobTotal',
       'pobDiscap', 'superficie', 'densidad', 'altitud', 'latitud',
       'longitud', 'numCenPobs', 'porcDesn5',
       'numPobres', 'numPobX', 'porcPobX',
       'propB600', 'propDiscap']
midisceplanmap_repro_shapes.columns=namesShapes

# %%
midisceplanmap_repro_shapes.to_file(filename='midisceplanmap_repro.shp.zip', driver='ESRI Shapefile')

# %%
sinadef=pd.read_excel("SINADEF_DATOS_ABIERTOS.xlsx")

# %%
sinadef.columns
# Out:
# Index(['Nº', 'TIPO SEGURO', 'SEXO', 'EDAD', 'TIEMPO EDAD', 'ESTADO CIVIL',
#        'NIVEL DE INSTRUCCIÓN', 'ETNIA', 'COD# UBIGEO DOMICILIO',
#        'PAIS DOMICILIO', 'DEPARTAMENTO DOMICILIO', 'PROVINCIA DOMICILIO',
#        'DISTRITO DOMICILIO', 'FECHA', 'AÑO', 'MES', 'TIPO LUGAR',
#        'INSTITUCION', 'MUERTE VIOLENTA', 'NECROPSIA', 'DEBIDO A (CAUSA A)',
#        'CAUSA A (CIE-X)', 'DEBIDO A (CAUSA B)', 'CAUSA B (CIE-X)',
#        'DEBIDO A (CAUSA C)', 'CAUSA C (CIE-X)', 'DEBIDO A (CAUSA D)',
#        'CAUSA D (CIE-X)', 'DEBIDO A (CAUSA E)', 'CAUSA E (CIE-X)',
#        'DEBIDO A (CAUSA F)', 'CAUSA F (CIE-X)'],
#       dtype='object')

# %%
sinadata['PAIS DOMICILIO'].value_counts()
# Out:
# PERU    521955
# Name: PAIS DOMICILIO, dtype: int64

# %%
sinadata=sinadef[sinadef.AÑO.isin([2018,2019,2020,2021])]

# %%
cambios={'DEPARTAMENTO DOMICILIO':'DEPARTAMENTO', 
    'PROVINCIA DOMICILIO':'PROVINCIA','DISTRITO DOMICILIO':'DISTRITO'}
sinadata.rename(columns=cambios,inplace=True)
# Out:
# /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ipykernel_4242/430454460.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sinadata.rename(columns=cambios,inplace=True)

# %%
sinadata.shape
# Out:
# (702744, 32)

# %%
sinadata=sinadata[sinadata["FECHA"].isin(pd.date_range('2019-03-01', '2021-03-31'))]
sinadata=sinadata[sinadata['PAIS DOMICILIO']=='PERU']
sinadata.drop(columns=['PAIS DOMICILIO'],inplace=True)

# %%
sinadata['preCovid']=sinadata["FECHA"]<'2020-03-01'
sinadata['postCovid']=sinadata["FECHA"]>='2020-03-01'

# %%
sinadata.loc[sinadata.PROVINCIA=='CALLAO','DEPARTAMENTO']='CALLAO'

# %%
sinadata.loc[sinadata.PROVINCIA=='NAZCA','PROVINCIA']='NASCA'

# %%
sinadata.loc[(sinadata.DISTRITO=='BARRANCA') & (sinadata.PROVINCIA=="ALTO AMAZONAS"),'PROVINCIA']='DATEM DEL MARAÑON'
sinadata.loc[(sinadata.DISTRITO=='BAÑOS') & (sinadata.PROVINCIA=="DOS DE MAYO"),'PROVINCIA']='LAURICOCHA'
sinadata.loc[(sinadata.DISTRITO=='CAHUAC') & (sinadata.PROVINCIA=="DOS DE MAYO"),'PROVINCIA']='LAURICOCHA'
sinadata.loc[(sinadata.DISTRITO=='CAHUAPANAS') & (sinadata.PROVINCIA=="ALTO AMAZONAS"),'PROVINCIA']='DATEM DEL MARAÑON'
sinadata.loc[sinadata.DISTRITO=='CASCAS','PROVINCIA']='GRAN CHIMU'
sinadata.loc[sinadata.DISTRITO=='CASCAS','DEPARTAMENTO']='LA LIBERTAD'

sinadata.loc[(sinadata.DISTRITO=='CHAVINILLO') & (sinadata.PROVINCIA=="DOS DE MAYO"),'PROVINCIA']='YAROWILCA'
sinadata.loc[sinadata.DISTRITO=='HUACHOCOLPA','PROVINCIA']='HUANCAVELICA'
sinadata.loc[sinadata.DISTRITO=='HUACHOCOLPA','DEPARTAMENTO']='HUANCAVELICA'

sinadata.loc[(sinadata.DISTRITO=='HUALLANCA') & (sinadata.PROVINCIA=="DOS DE MAYO"),'PROVINCIA']='HUAYLAS'
sinadata.loc[(sinadata.DISTRITO=='HUALLANCA') & (sinadata.DEPARTAMENTO=="HUANUCO"),'DEPARTAMENTO']='ANCASH'

sinadata.loc[(sinadata.DISTRITO=='HUANDO') & (sinadata.PROVINCIA=="TAYACAJA"),'PROVINCIA']='HUANCAVELICA'

sinadata.loc[sinadata.DISTRITO=='JACAS CHICO','PROVINCIA']='YAROWILCA'

sinadata.loc[(sinadata.DISTRITO=='JESUS') & (sinadata.PROVINCIA=="DOS DE MAYO"),'PROVINCIA']='LAURICOCHA'

sinadata.loc[(sinadata.DISTRITO=='JIVIA') & (sinadata.PROVINCIA=="DOS DE MAYO"),'PROVINCIA']='LAURICOCHA'

sinadata.loc[sinadata.DISTRITO=='MANSERICHE','PROVINCIA']='DATEM DEL MARAÑON'

sinadata.loc[sinadata.DISTRITO=='MASISEA','DEPARTAMENTO']='UCAYALI'

# %%
sinadata.loc[sinadata.DISTRITO=='SAN JOSE DE LOS CHORRILLOS','DISTRITO']='CUENCA'

# %%
sinadata.loc[sinadata.DISTRITO=='APARICIO POMARES (CHUPAN)','PROVINCIA']='YAROWILCA'

# %%
sinadata.loc[sinadata.DISTRITO=='APARICIO POMARES (CHUPAN)','DISTRITO']='APARICIO POMARES'

# %%
sinadata.PROVINCIA.value_counts().index
# Out:
# Index(['LIMA', 'CALLAO', 'AREQUIPA', 'TRUJILLO', 'PIURA', 'HUANCAYO', 'SANTA',
#        'ICA', 'CHICLAYO', 'MAYNAS',
#        ...
#        'JORGE BASADRE', 'CORONGO', 'CANDARAVE', 'OCROS', 'HUANCA SANCOS',
#        'CAJATAMBO', 'PUTUMAYO', 'PURUS', 'SIN REGISTRO', ' '],
#       dtype='object', length=198)

# %%
sinadata=sinadata.loc[~sinadata.PROVINCIA.isin(['SIN REGISTRO', ' '])]
sinadata=sinadata.loc[~sinadata.DISTRITO.isin(['SIN REGISTRO', ' '])]

# %%
unidades=['DEPARTAMENTO', 'PROVINCIA','DISTRITO']

sinadataAgg=sinadata.groupby(unidades).agg({'preCovid':'mean','postCovid':'mean'})
sinadataAgg.reset_index(inplace=True)
sinadataAgg
# Out:
#      DEPARTAMENTO   PROVINCIA    DISTRITO  preCovid  postCovid
# 0        AMAZONAS       BAGUA    ARAMANGO  0.333333   0.666667
# 1        AMAZONAS       BAGUA       BAGUA  0.296429   0.703571
# 2        AMAZONAS       BAGUA    COPALLIN  0.192308   0.807692
# 3        AMAZONAS       BAGUA    EL PARCO  0.333333   0.666667
# 4        AMAZONAS       BAGUA       IMAZA  0.283951   0.716049
# ...           ...         ...         ...       ...        ...
# 1889      UCAYALI  PADRE ABAD    CURIMANA  0.484848   0.515152
# 1890      UCAYALI  PADRE ABAD     IRAZOLA  0.472222   0.527778
# 1891      UCAYALI  PADRE ABAD     NESHUYA  0.257143   0.742857
# 1892      UCAYALI  PADRE ABAD  PADRE ABAD  0.335766   0.664234
# 1893      UCAYALI       PURUS       PURUS  0.470588   0.529412
#
# [1894 rows x 5 columns]

# %%
sinadataAgg[sinadataAgg.DEPARTAMENTO.str.contains('CALLAO')]
# Out:
#     DEPARTAMENTO PROVINCIA                    DISTRITO  preCovid  postCovid
# 688       CALLAO    CALLAO                  BELLAVISTA  0.282270   0.717730
# 689       CALLAO    CALLAO                      CALLAO  0.256463   0.743537
# 690       CALLAO    CALLAO  CARMEN DE LA LEGUA-REYNOSO  0.236311   0.763689
# 691       CALLAO    CALLAO                    LA PERLA  0.308624   0.691376
# 692       CALLAO    CALLAO                    LA PUNTA  0.351562   0.648438
# 693       CALLAO    CALLAO                     MI PERU  0.174242   0.825758
# 694       CALLAO    CALLAO                  VENTANILLA  0.223602   0.776398

# %%
notSina=set(midisceplanmap_repro.DISTRITO)-set(sinadataAgg.DISTRITO)
# Out:
# {'CHACA', 'GRANADA', 'ORONCCOY', 'ROSA PANDURO'}

# %%
notMap=set(sinadataAgg.DISTRITO)-set(midisceplanmap_repro.DISTRITO)
# Out:
# set()

# %%
sinadataAgg[sinadataAgg.PROVINCIA.str.contains("CHACHAPOYAS")]
# Out:
#    DEPARTAMENTO    PROVINCIA                 DISTRITO  preCovid  postCovid
# 18     AMAZONAS  CHACHAPOYAS                 ASUNCION  1.000000   0.000000
# 19     AMAZONAS  CHACHAPOYAS                   BALSAS  0.400000   0.600000
# 20     AMAZONAS  CHACHAPOYAS              CHACHAPOYAS  0.364641   0.635359
# 21     AMAZONAS  CHACHAPOYAS                    CHETO  0.500000   0.500000
# 22     AMAZONAS  CHACHAPOYAS                CHILIQUIN  0.750000   0.250000
# 23     AMAZONAS  CHACHAPOYAS              CHUQUIBAMBA  0.000000   1.000000
# 24     AMAZONAS  CHACHAPOYAS                  HUANCAS  0.800000   0.200000
# 25     AMAZONAS  CHACHAPOYAS                 LA JALCA  0.369565   0.630435
# 26     AMAZONAS  CHACHAPOYAS               LEIMEBAMBA  0.307692   0.692308
# 27     AMAZONAS  CHACHAPOYAS                  LEVANTO  0.375000   0.625000
# 28     AMAZONAS  CHACHAPOYAS                MAGDALENA  0.285714   0.714286
# 29     AMAZONAS  CHACHAPOYAS        MARISCAL CASTILLA  0.285714   0.714286
# 30     AMAZONAS  CHACHAPOYAS              MOLINOPAMPA  0.400000   0.600000
# 31     AMAZONAS  CHACHAPOYAS               MONTEVIDEO  0.545455   0.454545
# 32     AMAZONAS  CHACHAPOYAS                  OLLEROS  0.500000   0.500000
# 33     AMAZONAS  CHACHAPOYAS                QUINJALCA  0.000000   1.000000
# 34     AMAZONAS  CHACHAPOYAS  SAN FRANCISCO DE DAGUAS  0.250000   0.750000
# 35     AMAZONAS  CHACHAPOYAS      SAN ISIDRO DE MAINO  0.333333   0.666667
# 36     AMAZONAS  CHACHAPOYAS                   SOLOCO  0.304348   0.695652
# 37     AMAZONAS  CHACHAPOYAS                   SONCHE  0.000000   1.000000

# %%
midisceplanmap_repro[midisceplanmap_repro.DISTRITO.str.contains("GRANADA")]
# Out:
#      DEPARTAMENTO    PROVINCIA DISTRITO INSTITUCIO  \
# 1587     AMAZONAS  CHACHAPOYAS  GRANADA        IGN
#
#                                                geometry  UBIGEO_yana  UBIGEO  \
# 1587  POLYGON ((-450869.331 9325567.350, -450782.736...        10107   10107
#
#       programado_yana  ejecutado_yana  yanaProp  ...  altitud   latitud  \
# 1587              294             280  0.952381  ...   3041.0 -6.106389
#
#        longitud  numeroCentrosPoblados  porcentajeDesnutCronica5menos  \
# 1587 -77.628611                   12.0                       8.695652
#
#       conteoPobres  conteoPobresExtremos  porcentajePobrezaExtrema b600prop  \
# 1587           250                    33                  5.943345      NaN
#
#      propDisca
# 1587   0.02972
#
# [1 rows x 34 columns]

# %%
sinadataAgg.loc[1350,'DISTRITO']='SAN PEDRO DE LARAOS'

# %%
changesAgg={dis: process.extractOne(dis,notSina)[0] for dis in sorted(notMap)}
changesAgg
# Out:
# {'ANCO HUALLO': 'ANCO-HUALLO',
#  'ANTONIO RAIMONDI': 'ANTONIO RAYMONDI',
#  'CASTA': 'SAN PEDRO DE CASTA',
#  'HUAILLATI': 'HUAYLLATI',
#  'HUAY HUAY': 'HUAY-HUAY',
#  'NAZCA': 'NASCA',
#  'QUITO ARMA': 'QUITO-ARMA',
#  'SAN FCO DE ASIS DE YARUSYACAN': 'SAN FRANCISCO DE ASIS DE YARUSYACAN',
#  'SAN FRANCISCO DE YESO': 'SAN FRANCISCO DEL YESO',
#  'SAN JUAN DE ISCOS': 'SAN JUAN DE YSCOS'}

# %%
sinadataAgg.DISTRITO.replace(changesAgg,inplace=True)

# %%
test=midisceplanmap_repro.merge(sinadataAgg,on=theKeys,how='outer',indicator=True)
test
# Out:
#      DEPARTAMENTO         PROVINCIA                              DISTRITO  \
# 0           TACNA             TACNA  CORONEL GREGORIO ALBARRACIN LANCHIPA
# 1           TACNA             TACNA                              POCOLLAY
# 2           TACNA             TACNA                                CALANA
# 3           TACNA             TACNA                                 TACNA
# 4           TACNA             TACNA                                  SAMA
# ...           ...               ...                                   ...
# 1894       LORETO     ALTO AMAZONAS                                MORONA
# 1895       LORETO     ALTO AMAZONAS                               PASTAZA
# 1896       LORETO  CORONEL PORTILLO                               MASISEA
# 1897       LORETO            MAYNAS                              PUTUMAYO
# 1898       LORETO            MAYNAS               TENIENTE MANUEL CLAVERO
#
#      INSTITUCIO                                           geometry  \
# 0           IGN  POLYGON ((375786.764 7995151.165, 375737.244 7...
# 1           IGN  POLYGON ((400999.999 8017800.004, 404203.130 8...
# 2           IGN  POLYGON ((381787.363 8019300.707, 381943.948 8...
# 3           IGN  POLYGON ((360747.652 8015409.626, 361610.405 8...
# 4           IGN  POLYGON ((349041.999 8021481.079, 343238.800 8...
# ...         ...                                                ...
# 1894        NaN                                               None
# 1895        NaN                                               None
# 1896        NaN                                               None
# 1897        NaN                                               None
# 1898        NaN                                               None
#
#       UBIGEO_yana    UBIGEO  programado_yana  ejecutado_yana  yanaProp  ...  \
# 0        230110.0  220113.0          50230.0         46451.0  0.924766  ...
# 1        230108.0  220109.0           7204.0          6746.0  0.936424  ...
# 2        230103.0  220102.0           1879.0          1753.0  0.932943  ...
# 3        230101.0  220101.0          40771.0         37323.0  0.915430  ...
# 4        230109.0  220110.0           1766.0          1625.0  0.920159  ...
# ...           ...       ...              ...             ...       ...  ...
# 1894          NaN       NaN              NaN             NaN       NaN  ...
# 1895          NaN       NaN              NaN             NaN       NaN  ...
# 1896          NaN       NaN              NaN             NaN       NaN  ...
# 1897          NaN       NaN              NaN             NaN       NaN  ...
# 1898          NaN       NaN              NaN             NaN       NaN  ...
#
#       numeroCentrosPoblados  porcentajeDesnutCronica5menos  conteoPobres  \
# 0                      32.0                       3.302912       19552.0
# 1                      13.0                       2.813299        2393.0
# 2                      37.0                       3.333333         324.0
# 3                      18.0                       2.764423       10072.0
# 4                      33.0                       3.731343         292.0
# ...                     ...                            ...           ...
# 1894                    NaN                            NaN           NaN
# 1895                    NaN                            NaN           NaN
# 1896                    NaN                            NaN           NaN
# 1897                    NaN                            NaN           NaN
# 1898                    NaN                            NaN           NaN
#
#       conteoPobresExtremos  porcentajePobrezaExtrema  b600prop  propDisca  \
# 0                   1715.0                  1.644405  0.926729   0.009132
# 1                    168.0                  0.944194  0.929134   0.009241
# 2                     19.0                  0.432479  0.950739   0.006980
# 3                    296.0                  0.226073  0.912929   0.010965
# 4                     31.0                  1.143432  0.944355   0.003276
# ...                    ...                       ...       ...        ...
# 1894                   NaN                       NaN       NaN        NaN
# 1895                   NaN                       NaN       NaN        NaN
# 1896                   NaN                       NaN       NaN        NaN
# 1897                   NaN                       NaN       NaN        NaN
# 1898                   NaN                       NaN       NaN        NaN
#
#       preCovid postCovid      _merge
# 0     0.358726  0.641274        both
# 1     0.311927  0.688073        both
# 2     0.366197  0.633803        both
# 3     0.301742  0.698258        both
# 4     0.470588  0.529412        both
# ...        ...       ...         ...
# 1894  0.333333  0.666667  right_only
# 1895  1.000000  0.000000  right_only
# 1896  0.476190  0.523810  right_only
# 1897  0.222222  0.777778  right_only
# 1898  0.500000  0.500000  right_only
#
# [1899 rows x 37 columns]

# %%
set(test[test['_merge']=='left_only'].DISTRITO)
# Out:
# {'CHACA', 'COCHAS', 'GRANADA', 'ORONCCOY', 'ROSA PANDURO'}

# %%
set(test[test['_merge']=='right_only'].DISTRITO)
# Out:
# {'BARRANCA',
#  'BAÑOS',
#  'CAHUAC',
#  'CAHUAPANAS',
#  'CASCAS',
#  'CHAVINILLO',
#  'HUACHOCOLPA',
#  'HUALLANCA',
#  'HUANDO',
#  'JACAS CHICO',
#  'JESUS',
#  'JIVIA',
#  'MANSERICHE',
#  'MASISEA',
#  'MORONA',
#  'OBAS',
#  'PACHAMARCA',
#  'PAMPAMARCA',
#  'PASTAZA',
#  'PUTUMAYO',
#  'RONDOS',
#  'SAN FRANCISCO DE ASIS',
#  'SAN MIGUEL DE CAURI',
#  'SAYAPULLO',
#  'TENIENTE MANUEL CLAVERO'}

# %%
set(test[test['_merge']=='left_only'].DISTRITO)&set(test[test['_merge']=='right_only'].DISTRITO)
# Out:
# set()

# %%
sinadataAgg[sinadataAgg.DISTRITO.str.contains("MASISEA")]
# Out:
#      DEPARTAMENTO         PROVINCIA DISTRITO  preCovid  postCovid
# 1475       LORETO  CORONEL PORTILLO  MASISEA  0.476190   0.523810
# 1885      UCAYALI  CORONEL PORTILLO  MASISEA  0.353846   0.646154

# %%
midisceplanmap_repro[midisceplanmap_repro.DISTRITO.str.contains("MASISEA")]
# Out:
#      DEPARTAMENTO         PROVINCIA DISTRITO INSTITUCIO  \
# 1238      UCAYALI  CORONEL PORTILLO  MASISEA        IGN
#
#                                                geometry  UBIGEO_yana  UBIGEO  \
# 1238  POLYGON ((264.140 9073719.412, 484.431 9073658...       250104  250103
#
#       programado_yana  ejecutado_yana  yanaProp  ...  altitud   latitud  \
# 1238             7915            7051   0.89084  ...    150.0 -8.604722
#
#        longitud  numeroCentrosPoblados  porcentajeDesnutCronica5menos  \
# 1238 -74.306111                   82.0                      36.535859
#
#       conteoPobres  conteoPobresExtremos  porcentajePobrezaExtrema b600prop  \
# 1238          5850                   399                  2.235026      NaN
#
#      propDisca
# 1238  0.003249
#
# [1 rows x 34 columns]
